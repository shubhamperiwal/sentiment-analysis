# %% [markdown]
# # Sentiment Analysis - Classifier

# %% [markdown]
# This notebook will try to create my own classifier based on news articles which I can then use in one of my projects.
# Process:
#
# 1. Get training dataset from CSV file
# 2. Get stopwords from nltk. Edit list according to news articles.
# 3. Lemmatize the remaining words and only add to list if words are greater than 3 letters and are not stopwords
# 4. Attach sentiment to the word list
# 5. For each word, store how many times it was present in positive articles and how many times in negative.
# 6. Accordingly, train classifier using this data
# 7. Get new articles and classify them
# 8. Classify them according to NLTK Sentiment Intensity Analyser
# 9. Test accuracy by comparing both of them

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from afinn import Afinn
from newsapi import NewsApiClient
from nltk.stem import WordNetLemmatizer
import json
from pymongo import MongoClient
# Out:
# C:\Users\smart\AppData\Local\Continuum\anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
sid = SentimentIntensityAnalyzer()
afinn = Afinn()
newsapi = NewsApiClient(api_key='c739ce625cc44a2489a36795b6fbcf7e')
lemmatizer = WordNetLemmatizer()
client = MongoClient('mongodb://kodigo_smu:kodigo123@ds139331.mlab.com:39331/kodigo_smu')
db = client['kodigo_smu']

# %%
news_articles_train = db['news_articles_train']

# %%
all_articles = pd.DataFrame(list(news_articles_train.find({})))

# %%
all_articles.head()
# Out:
#                         _id                                  author  \
# 0  5bb4df58fd6d92a4a6d9a286                             Rhett Jones
# 1  5bb4df58fd6d92a4a6d9a287  ANEMONA HARTOCOLLIS and DANA GOLDSTEIN
# 2  5bb4df58fd6d92a4a6d9a288                              Saqib Shah
# 3  5bb4df58fd6d92a4a6d9a289                            Brian Geddes
# 4  5bb4df58fd6d92a4a6d9a28a                           Xavier Piedra
#
#                                              content  \
# 0  “We’re a culture of builders,” Janelle Gale, F...
# 1  At St. Pauls, an Episcopal boarding school in ...
# 2  A total of 50 episodes have been commissioned ...
# 3  September 7, 2018 5 min read Opinions expresse...
# 4  I don't mean to alarm anyone, but it's totally...
#
#                                          description           publishedAt  \
# 0  “We’re a culture of builders,” Janelle Gale, F...  2018-09-04T23:50:00Z
# 1  The allegations against Judge Brett Kavanaugh ...  2018-09-28T21:23:42Z
# 2  Following in the footsteps of Zane Lowe and Ry...  2018-09-21T12:20:00Z
# 3  For generations marijuana was a cheerfully out...  2018-09-07T12:00:00Z
# 4  I don't mean to alarm anyone, but it's totally...  2018-09-19T15:25:05Z
#
#   sentiment                                             source  \
# 0   neutral                {'id': None, 'name': 'Gizmodo.com'}
# 1   neutral  {'id': 'the-new-york-times', 'name': 'The New ...
# 2   neutral             {'id': 'engadget', 'name': 'Engadget'}
# 3   neutral      {'id': None, 'name': 'Greenentrepreneur.com'}
# 4  negative             {'id': 'mashable', 'name': 'Mashable'}
#
#                                                title  \
# 0  Facebook's New Office Looks Like a Tree House ...
# 1  Schools Are Tackling ‘Bro’ Culture. The Kavana...
# 2  Spotify taps DJ Semtex for hip-hop culture pod...
# 3  Cannabis Culture Is Fast Becoming Corporate Cu...
# 4  This weirdly peppy anthem for end times will b...
#
#                                                  url  \
# 0  https://gizmodo.com/facebooks-new-office-looks...
# 1  https://www.nytimes.com/2018/09/28/us/kavanaug...
# 2  https://www.engadget.com/2018/09/21/spotify-dj...
# 3   https://www.greenentrepreneur.com/article/319598
# 4  https://mashable.com/video/bill-wurtz-mount-st...
#
#                                           urlToImage
# 0  https://i.kinja-img.com/gawker-media/image/upl...
# 1  https://static01.nyt.com/images/2018/09/27/us/...
# 2  https://o.aolcdn.com/images/dims?thumbnail=120...
# 3  https://assets.entrepreneur.com/content/3x2/20...
# 4  https://i.amz.mshcdn.com/1a44EASiuhIu8huDbfDbw...

# %%
# all_articles_csv = pd.read_csv('data/all_articles_with_sentiment.csv')
# all_articles_csv.head()

# %% [markdown]
# Prepare Test Data

# %%
articles_list = list(zip(all_articles['title'], all_articles['sentiment']))

# %%
#Create stopwords
stopWords = list(stopwords.words('english'))

useful_words = ['but', 'because', 'up', 'down', 'under', 'not', 'only', 'aren', "aren't", 'couldn', "couldn't", 'didn',
                  "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't",
                 "mightn't", "mustn't","needn't", "shan't", "shouldn't", "wasn't",  "weren't", "won't", "wouldn't"]
stopWords = [x for x in stopWords if x not in useful_words]

# %%
article_word_list = []
for (words, sentiment) in articles_list:
    words_filtered = [lemmatizer.lemmatize(e).lower() for e in words.split() if len(e) >= 3 if e not in stopWords] 
    article_word_list.append((words_filtered, sentiment))

# %%
article_word_list
# Out:
# [(["facebook's",
#    'new',
#    'office',
#    'looks',
#    'like',
#    'tree',
#    'house',
#    'built',
#    'incompetent',
#    'dad'],
#   'neutral'),
#  (['schools',
#    'are',
#    'tackling',
#    '‘bro’',
#    'culture.',
#    'the',
#    'kavanaugh',
#    'case',
#    'shows',
#    'why',
#    'that’s',
#    'hard',
#    'do.'],
#   'neutral'),
#  (['spotify', 'tap', 'semtex', 'hip-hop', 'culture', 'podcast'], 'neutral'),
#  (['cannabis', 'culture', 'fast', 'becoming', 'corporate', 'culture'],
#   'neutral'),
#  (['this',
#    'weirdly',
#    'peppy',
#    'anthem',
#    'end',
#    'time',
#    'stuck',
#    'head',
#    'day'],
#   'negative'),
#  (['‘murphy', 'brown’', 'returns', 'fight', 'new', 'culture', 'wars'],
#   'negative'),
#  (['these', 'high', 'school', 'senior', 'took', 'photo', 'next', 'level'],
#   'neutral'),
#  (['please', 'enjoy', "grandmother's", 'perfect', 'bottle', 'flip'],
#   'positive'),
#  (['‘the', 'simpsons’', '30:', 'six', 'era-defining', 'episodes'], 'neutral'),
#  (['what', 'make', 'apple’s', 'design', 'culture', 'special'], 'positive'),
#  (['the', "'scotch-irish'", 'influence', 'democracy'], 'neutral'),
#  (['watch', 'these', 'timeless', 'shows', 'with', 'your', 'kids'], 'neutral'),
#  (["parent's", 'guide', 'teaching', 'your', 'kid', 'about', 'consent'],
#   'positive'),
#  (['big', 'city:', 'henri', 'bendel', 'death', 'luxury'], 'negative'),
#  (['why', 'i’m', 'willing', 'suffer', 'through', '‘cats’', 'china'],
#   'negative'),
#  (['california',
#    'today:',
#    'california',
#    'today:',
#    'show',
#    'about',
#    '‘women,',
#    'sex',
#    'power’',
#    'gains',
#    'new',
#    'urgency'],
#   'positive'),
#  (['yale’s',
#    'culture',
#    'privilege',
#    'alcohol,',
#    'her',
#    'world',
#    'converged',
#    'with',
#    'kavanaugh’s'],
#   'positive'),
#  (['the',
#    'xbox',
#    'adaptive',
#    'controller',
#    'go',
#    'sale',
#    'today',
#    'also',
#    'part',
#    'v&a',
#    'museum’s',
#    'collection'],
#   'neutral'),
#  (['brett',
#    'kavanaugh',
#    'draw',
#    'sharp',
#    'rebuke',
#    "'the",
#    'twilight',
#    "zone'",
#    'family'],
#   'neutral'),
#  (["here's",
#    'biggest',
#    'pumpkin',
#    'u.s.',
#    'history',
#    'because',
#    'need',
#    'something',
#    'nice'],
#   'positive'),
#  (['ambulance',
#    'officer',
#    'lauded',
#    'granting',
#    'dying',
#    "man's",
#    'wish',
#    'sundae'],
#   'positive'),
#  (['the',
#    'interactive',
#    'rain',
#    'website',
#    'brings',
#    'temporary',
#    'peace',
#    'online'],
#   'positive'),
#  (['guy',
#    'email',
#    '246',
#    'nicoles',
#    'search',
#    'girl',
#    'met',
#    'bar,',
#    "they're",
#    'friend'],
#   'positive'),
#  (["beyoncé's", 'meme-able', 'moment'], 'neutral'),
#  (['watch',
#    'car',
#    'wash',
#    'employee',
#    'expertly',
#    'escape',
#    'getting',
#    'caught',
#    'two',
#    'vehicle'],
#   'neutral'),
#  (['notes', 'culture:', 'how', 'one', 'man', 'recreating', 'lost', 'colors'],
#   'negative'),
#  (['these', 'nun', 'buy', 'stock', 'gun', 'company', 'fight', 'gun', 'safety'],
#   'negative'),
#  (['this',
#    'tiger',
#    'woods',
#    'doppelgänger',
#    'totally',
#    'upstaged',
#    'real',
#    'tiger',
#    'golf',
#    'tournament'],
#   'neutral'),
#  (['robert',
#    'mueller',
#    'spotted',
#    'apple',
#    'store',
#    'getting',
#    'tech',
#    'support'],
#   'positive'),
#  (['chrissy',
#    'teigen',
#    'grace',
#    'internet',
#    'another',
#    'award',
#    'show',
#    'meme'],
#   'positive'),
#  (['turns', 'maya', 'rudolph', 'great', 'jimmy', 'fallon', 'impression'],
#   'positive'),
#  (['old',
#    'lady',
#    'gaga',
#    'tweet',
#    'got',
#    'turned',
#    'honestly',
#    'great',
#    'meme'],
#   'positive'),
#  (['retro', 'logo', 'modern', 'internet', 'company'], 'neutral'),
#  (['notes',
#    'culture:',
#    'does',
#    'cost',
#    'living',
#    'new',
#    'york',
#    'spell',
#    'end',
#    'its',
#    'artistic',
#    'life?'],
#   'neutral'),
#  (['next',
#    'junction:',
#    'explore',
#    'indian',
#    'railways',
#    'google',
#    'arts',
#    'culture'],
#   'neutral'),
#  (['monday',
#    'briefing:',
#    '40%',
#    'think',
#    'multiculturalism',
#    'undermines',
#    'british',
#    'culture'],
#   'negative'),
#  (['grow',
#    'your',
#    'makerspace:',
#    'tips',
#    'for',
#    'building',
#    'positive',
#    'maker',
#    'culture'],
#   'positive'),
#  (['no,',
#    "weren't",
#    'hallucinating',
#    'lindsey',
#    "graham's",
#    'ferocious',
#    'tirade'],
#   'negative'),
#  (['eminem', 'dropped', 'surprise', 'album', 'called', "'kamikaze'", 'people'],
#   'positive'),
#  (['bishop',
#    'apologizes',
#    'touching',
#    'ariana',
#    'grande',
#    'inappropriately',
#    'aretha',
#    "franklin's",
#    'funeral'],
#   'neutral'),
#  (['delia*s', 'may', 'thing', 'past,', 'but', 'aesthetic', 'stronger', 'ever'],
#   'positive'),
#  (['this',
#    'exfoliating',
#    'mitten',
#    'make',
#    'skin',
#    'feel',
#    'like',
#    'damn',
#    'cloud'],
#   'neutral'),
#  (['shocking',
#    'number',
#    'people',
#    'got',
#    'tattoo',
#    "domino's",
#    'logo',
#    'hope',
#    'scoring',
#    'free',
#    'pizza',
#    'life'],
#   'positive'),
#  (['one', 'meme', 'like', 'gaston...', 'never', 'get', 'song', 'head'],
#   'neutral'),
#  (['was', 'vanilla', 'ice', 'quarantined', 'plane?', 'investigation.'],
#   'neutral'),
#  (['tough',
#    'guy',
#    'alex',
#    'jones',
#    'marco',
#    'rubio',
#    'awkward',
#    'confrontation'],
#   'negative'),
#  (['wikileaks',
#    'get',
#    'roasted',
#    'obvious',
#    'prediction',
#    'wrote',
#    'nyt',
#    'trump',
#    'op-ed'],
#   'neutral'),
#  (['the', 'woman', 'dipped', 'chicken', 'finger', 'soda', 'explains', 'deal'],
#   'neutral'),
#  (['venezuela’s',
#    'president',
#    'dines',
#    'salt',
#    "bae's",
#    'restaurant',
#    'million',
#    'country',
#    'starving'],
#   'negative'),
#  (['comedian', 'troll', 'emmys', 'red', 'carpet', 'getty', 'images', 'purse'],
#   'positive'),
#  (['florida',
#    'man',
#    'back',
#    'heavy',
#    'metal',
#    'american',
#    'flag',
#    'face',
#    'hurricane',
#    'florence'],
#   'neutral'),
#  (['hero', 'fight', 'weed', 'dispensary', 'robber', 'bong'], 'positive'),
#  (['donald',
#    'trump',
#    'fist',
#    'pumped',
#    'way',
#    '9/11',
#    'memorial',
#    'service',
#    'not',
#    'going',
#    'well'],
#   'negative'),
#  (['mac',
#    "miller's",
#    'mom',
#    'posted',
#    'touching',
#    'tribute',
#    'son',
#    'instagram'],
#   'neutral'),
#  (['watch',
#    'obama',
#    'tell',
#    'great',
#    'story',
#    'getting',
#    'kicked',
#    'disneyland'],
#   'positive'),
#  (['christine',
#    'blasey',
#    'ford',
#    'detail',
#    'harassment',
#    'received',
#    'kavanaugh',
#    'allegation'],
#   'negative'),
#  (['moment',
#    'new',
#    "'captain",
#    "marvel'",
#    'trailer',
#    'really',
#    'people',
#    'confused'],
#   'neutral'),
#  (['aussies',
#    'baffled',
#    'something',
#    'called',
#    "'australian",
#    'battered',
#    "potatoes'"],
#   'neutral'),
#  (['chris',
#    "evans'",
#    'pup',
#    'deserves',
#    'grammy',
#    'howling',
#    'dog',
#    'park',
#    'duet'],
#   'neutral'),
#  (['gigi',
#    'bella',
#    'hadid',
#    'recreate',
#    'iconic',
#    "'beetlejuice'",
#    'scene',
#    'excuse',
#    'burst',
#    'song'],
#   'neutral'),
#  (['teens',
#    'break',
#    'dispensary',
#    'end',
#    'stealing',
#    'oregano',
#    'instead',
#    'weed'],
#   'negative'),
#  (['these',
#    'guy',
#    'recreated',
#    "'the",
#    'creation',
#    "adam'",
#    'swimming',
#    'pool',
#    'undeniably',
#    'epic'],
#   'positive'),
#  (['people',
#    'think',
#    'namibian',
#    'model',
#    'look',
#    'like',
#    'regina',
#    'george',
#    "'mean",
#    "girls'"],
#   'positive'),
#  (['cathay', 'pacific', 'made', 'pretty', 'hilarious', 'typo', 'plane'],
#   'positive'),
#  (['football',
#    'player',
#    'stuns',
#    'fan',
#    'retiring',
#    'entire',
#    'sport',
#    'halftime'],
#   'neutral'),
#  (['made', 'spotify', 'playlist', 'next', 'karaoke', 'party'], 'positive'),
#  (['amazon',
#    'ship',
#    'live',
#    'christmas',
#    'tree',
#    'door',
#    'but',
#    'stay',
#    'put',
#    'damn',
#    'lights?'],
#   'negative'),
#  (['‘go',
#    'f*ck',
#    'selfie’:',
#    'someone',
#    'vandalized',
#    'popular',
#    'selfie',
#    'spot'],
#   'positive'),
#  (['nest',
#    'doorbell',
#    'lock',
#    'man',
#    'home',
#    'mistaking',
#    'batman',
#    'shirt',
#    'intruder'],
#   'negative'),
#  (['eric',
#    'trump',
#    'said',
#    'something',
#    'super',
#    'anti-semitic',
#    'fox',
#    'news',
#    'nobody',
#    'even',
#    'blinked'],
#   'positive'),
#  (['pre-internet', 'political', 'moment', 'would', 'spawned', 'huge', 'meme'],
#   'positive'),
#  (['dad',
#    'attempt',
#    'nice',
#    'but',
#    'absurdly',
#    'unsuccessful',
#    'panoramic',
#    'photo',
#    'daughter'],
#   'negative'),
#  (['man',
#    'try',
#    'use',
#    'zillow',
#    'prove',
#    "kavanaugh's",
#    'innocence',
#    'end',
#    'owning'],
#   'positive'),
#  (['watch',
#    'mob',
#    'golf',
#    'spectator',
#    'swarm',
#    'tiger',
#    'woods',
#    'clinch',
#    'first',
#    'win',
#    'five',
#    'year'],
#   'positive'),
#  (['amateur',
#    'artist',
#    'try',
#    'restore',
#    'ancient',
#    'jesus',
#    'sculpture,',
#    'omfg'],
#   'positive'),
#  (['bear',
#    'photobombs',
#    "couple's",
#    'wedding',
#    'photo',
#    'best',
#    'possible',
#    'way'],
#   'positive'),
#  (['this',
#    'job',
#    'pay',
#    '$50',
#    'hour',
#    'smoke',
#    'weed,',
#    'but',
#    'obnoxious',
#    'stoner'],
#   'negative'),
#  (['anna',
#    'kendrick',
#    'made',
#    'barack',
#    'obama',
#    'double',
#    'laughter',
#    '2012.',
#    'now',
#    'know',
#    'why.'],
#   'positive'),
#  (['this',
#    'guy',
#    'make',
#    "'september'",
#    'music',
#    'video',
#    'every',
#    'year,',
#    'year',
#    'best'],
#   'positive'),
#  (['supermarket', 'hummus', 'garbage.', 'instead,', 'make', 'own.'],
#   'neutral'),
#  (['next',
#    'time',
#    'someone',
#    'annoys',
#    'tinder,',
#    'rock',
#    'halloween',
#    "'ghosted'",
#    'costume'],
#   'negative'),
#  (['how', 'measure', 'app', 'affect', 'dick', 'pics?', 'investigation.'],
#   'negative'),
#  (['7-year-old',
#    "girl's",
#    'version',
#    'national',
#    'anthem',
#    'stunningly',
#    'good'],
#   'positive'),
#  (['ted',
#    "cruz's",
#    'latest',
#    'dig',
#    'beto',
#    "o'rourke",
#    'twitter',
#    'might',
#    'vilest',
#    'yet'],
#   'neutral'),
#  (['senator',
#    'orrin',
#    'hatch',
#    'called',
#    'dr.',
#    'christine',
#    'blasey',
#    'ford',
#    "'attractive",
#    "witness'"],
#   'positive'),
#  (['someone',
#    'mashed',
#    "kavanaugh's",
#    'testimony',
#    "'pulp",
#    "fiction'",
#    'work',
#    'disturbingly',
#    'well'],
#   'negative'),
#  (['the',
#    "hearing's",
#    'over,',
#    'but',
#    'people',
#    'still',
#    "aren't",
#    'buying',
#    "kavanaugh's",
#    'discredited',
#    'argument'],
#   'neutral'),
#  (['meghan',
#    'mccain',
#    'come',
#    'trump',
#    "father's",
#    'funeral:',
#    "'america",
#    'always',
#    "great'"],
#   'positive'),
#  (['kanye',
#    'west',
#    'heard',
#    'tiny-slipper',
#    'critique',
#    'raise',
#    'giant',
#    'version'],
#   'neutral'),
#  (['theresa', 'may', 'going', 'dance,', 'whether', 'internet', 'like', 'not'],
#   'positive'),
#  (["lyft's", 'bid', 'rule', 'streets', 'now', 'includes', 'public', 'transit'],
#   'neutral'),
#  (['people', 'weirded', 'fan', 'dipping', 'chicken', 'finger', 'soda'],
#   'positive'),
#  (['these',
#    'guy',
#    'snuck',
#    'fake',
#    'poster',
#    "mcdonald's",
#    'make',
#    'important',
#    'point'],
#   'negative'),
#  (['people',
#    'getting',
#    'roasted',
#    'hilariously',
#    'ineffective',
#    'nike',
#    'protest'],
#   'negative'),
#  (['dandruff',
#    'scratching',
#    'new',
#    'asmr',
#    'trend',
#    "can't",
#    'believe',
#    'love'],
#   'negative'),
#  (['strategy',
#    'rpg',
#    "'valkyria",
#    'chronicles',
#    'wonderful',
#    'return',
#    'form'],
#   'positive'),
#  (['bad', 'north', 'scaled-down', 'rts', 'that’s', 'perfect', 'switch'],
#   'neutral'),
#  (['what', 'area', 'expertise', 'you', 'never', 'get', 'talk', 'about?'],
#   'neutral'),
#  (['trump’s',
#    'growing',
#    'legal',
#    'team',
#    'has',
#    'problem:',
#    'it’s',
#    'operating',
#    'partly',
#    'dark'],
#   'neutral'),
#  (['white', 'house:', "we're", 'going', 'cyber', 'harder'], 'neutral'),
#  (['ashton', 'kutcher', 'hate', 'cars,', 'love', 'scooter'], 'positive'),
#  (['imran',
#    'khan',
#    'leaving',
#    'role',
#    'strategy',
#    'head',
#    'snap',
#    'start',
#    'investment',
#    'firm'],
#   'neutral'),
#  (['deliveroo', 'enter', 'taiwan,', 'fourth', 'market', 'asia-pacific', 'far'],
#   'neutral'),
#  (['facebook’s',
#    'plan',
#    'let',
#    'company',
#    'buy',
#    'live',
#    'independently',
#    'failed'],
#   'negative'),
#  (['white',
#    'house',
#    'sanction',
#    'quicker',
#    'response',
#    'foreign',
#    'cyber',
#    'attack'],
#   'negative'),
#  (["studios'", "'kingdoms", "amalur'", 'find', 'second', 'life', 'thq'],
#   'neutral'),
#  (['microsoft', 'hosting', 'surface', 'event', 'nyc', 'october', '2nd'],
#   'neutral'),
#  (['sunday', 'comics:', 'amazing', 'fighting', 'strategy'], 'positive'),
#  (['some',
#    'iphone',
#    'users',
#    'are',
#    'saying',
#    'colors',
#    'look',
#    "'off'",
#    'after',
#    'upgrading',
#    'ios'],
#   'neutral'),
#  (['flotsam', 'waterworld:', 'the', 'strategy', 'game'], 'neutral'),
#  (['walmart', 'bringing', 'delivery', 'strategy', 'international', 'market'],
#   'neutral'),
#  (['when',
#    'facing',
#    'stock',
#    'market',
#    'crash,',
#    "here's",
#    'how',
#    'still',
#    'make',
#    'money'],
#   'negative'),
#  (['uppercase',
#    'raise',
#    '$3.5m',
#    'help',
#    'e-tailers',
#    'open',
#    'brick-and-mortar',
#    'store'],
#   'positive'),
#  (['california', 'plan', 'launch', 'climate', 'satellite'], 'neutral'),
#  (['analytics', 'tools', 'supercharge', 'your', 'marketing', 'strategy'],
#   'neutral'),
#  (['snap', 'lost', 'chief', 'strategy', 'officer'], 'negative'),
#  (['how', 'create', 'user-intent', 'seo', 'strategy'], 'positive'),
#  (['verizon',
#    'decline',
#    'comment',
#    'wsj',
#    'report',
#    'saying',
#    'tim',
#    'armstrong',
#    'talk',
#    'leave',
#    'oath'],
#   'neutral'),
#  (['samsung',
#    'say',
#    'new',
#    'feature',
#    'could',
#    'come',
#    'mid-range',
#    'phone',
#    'flagship'],
#   'neutral'),
#  (['collusion:',
#    'new',
#    'texts',
#    'show',
#    'fbi',
#    'officials',
#    'had',
#    'media',
#    'leak',
#    'strategy',
#    'hurt',
#    'trump',
#    'during',
#    'russia',
#    'probe',
#    'townhall'],
#   'negative'),
#  (["microsoft's",
#    'snazzy',
#    'surface',
#    'hub',
#    'get',
#    'backwards-compatible',
#    'sibling',
#    '2019',
#    'cnet'],
#   'neutral'),
#  (['pressure', 'mount', 'may', 'critic', 'tear', 'brexit', 'plan'],
#   'negative'),
#  (['iphone', 'hands-on:', 'premium', 'power', 'everyone'], 'neutral'),
#  (['spotify', 'tap', 'semtex', 'hip-hop', 'culture', 'podcast'], 'neutral'),
#  (['heineken’s',
#    'new',
#    'brand',
#    'strategy',
#    'definitely',
#    'not',
#    'leave',
#    'guessing'],
#   'positive'),
#  (['u.s.',
#    'retreats',
#    'publicizing',
#    'body',
#    'count',
#    'militants',
#    'killed',
#    'afghanistan'],
#   'negative'),
#  (['boris',
#    'johnson',
#    'call',
#    'theresa',
#    "may's",
#    'brexit',
#    'plan',
#    'suicide',
#    'vest'],
#   'negative'),
#  (['can’t', 'fill', 'job', 'vacancy?', 'here', 'tip', 'make', 'easier'],
#   'positive'),
#  (['munich',
#    'buy',
#    'iot',
#    'middleware',
#    'startup,',
#    'relayr,',
#    'deal',
#    'worth',
#    '$300m'],
#   'positive'),
#  (['samsung', 'debut', 'note', 'silver', 'brings', 'black', 'model'],
#   'neutral'),
#  (['software', 'complexity', 'strategy'], 'neutral'),
#  (['samsung',
#    'plans',
#    'overhaul',
#    'its',
#    'smartphone',
#    'strategy',
#    'mid-range',
#    'price',
#    'point'],
#   'neutral'),
#  (['strzok',
#    'denies',
#    'allegation',
#    'coordinated',
#    'medium',
#    'leak',
#    'strategy'],
#   'negative'),
#  (['stem', 'toys', 'entertain', 'enlighten', 'your', 'kids'], 'positive'),
#  (['this',
#    'serial',
#    'entrepreneur',
#    'shares',
#    'the',
#    'surprising',
#    'confidence',
#    'strategy',
#    'that',
#    'helped',
#    'her',
#    'build',
#    'billion-dollar',
#    'business'],
#   'positive'),
#  (['the',
#    'influencer',
#    'marketing',
#    'report:',
#    'research,',
#    'strategy',
#    'platform',
#    'leveraging',
#    'social',
#    'medium',
#    'influencers'],
#   'neutral'),
#  (['the', 'case', 'impeaching', 'kavanaugh'], 'neutral'),
#  (['the',
#    'supreme',
#    'court',
#    'nominee’s',
#    'strategy',
#    'was',
#    'make',
#    'himself',
#    'the',
#    'victim'],
#   'positive'),
#  (['twitch', 'hire', 'head', 'diversity', 'inclusion'], 'neutral'),
#  (['disability',
#    'charity',
#    'under',
#    'fire',
#    'home',
#    'sell-off',
#    'strategy',
#    'david',
#    'brindle'],
#   'neutral'),
#  (['homepod',
#    'holds',
#    'estimated',
#    '70%',
#    'share',
#    'growing',
#    '$200+',
#    'smart',
#    'speaker',
#    'market'],
#   'positive'),
#  (['congrats', 'brett', 'kavanaugh', 'getting', 'angry'], 'neutral'),
#  (['bay',
#    'area',
#    '2070:',
#    'dire',
#    'visions,',
#    'potentially',
#    'great',
#    'future'],
#   'positive'),
#  (['pretty',
#    'art',
#    'screen',
#    'startup',
#    'meural',
#    'get',
#    'acquired',
#    'ugly',
#    'wifi',
#    'router',
#    'company'],
#   'neutral'),
#  (['robots', 'develop', 'prejudice', 'like', 'human'], 'neutral'),
#  (['instacart’s',
#    'chief',
#    'growth',
#    'officer',
#    'elliot',
#    'shmukler',
#    'leaving'],
#   'positive'),
#  (['leading',
#    'gun',
#    'safety',
#    'group',
#    'heading',
#    'key',
#    'districts',
#    'before',
#    'the',
#    'midterms'],
#   'neutral'),
#  (['oculus', 'content', 'forward-compatible', 'future', 'headset'], 'neutral'),
#  (['mixed',
#    'reality',
#    'company',
#    'embrace',
#    '‘yes,',
#    'and’',
#    'strategy',
#    'competition'],
#   'positive'),
#  (['lyft', 'hire', 'yet', 'another', 'ex-tesla', 'employee'], 'neutral'),
#  (['first',
#    'dji,',
#    'bang',
#    'olufsen',
#    'get',
#    'line',
#    'friends-themed',
#    'product'],
#   'neutral'),
#  (['how', 'create', 'content', 'marketing', 'strategy', 'virtual', 'reality'],
#   'positive'),
#  (['old', 'medium', 'giant', 'turn', 'next', 'act'], 'neutral'),
#  (['john',
#    'bolton',
#    'warning',
#    'offensive',
#    'cyberattacks',
#    'under',
#    'new',
#    'trump',
#    'policy'],
#   'negative'),
#  (['entrepreneurs:',
#    'it’s',
#    'time',
#    'put',
#    'corporate',
#    'vcs',
#    'back',
#    'short',
#    'list'],
#   'neutral'),
#  (['sony',
#    'playstation',
#    'us',
#    'blockbuster',
#    'strategy',
#    'new',
#    'spider-man',
#    'game'],
#   'positive'),
#  (['mission',
#    'slam',
#    'spacecraft',
#    'into',
#    'asteroid',
#    'has',
#    'begun',
#    'final',
#    'design',
#    'construction'],
#   'negative'),
#  (['trump',
#    'accuses',
#    'democrats',
#    'running',
#    '‘con',
#    'game’',
#    'against',
#    'kavanaugh'],
#   'negative'),
#  (["'he",
#    'medium',
#    "background':",
#    'industry',
#    'executive',
#    'react',
#    'snapchat',
#    'losing',
#    'chief',
#    'strategy',
#    'officer',
#    'imran',
#    'khan'],
#   'negative'),
#  (['boris',
#    'johnson',
#    'say',
#    'theresa',
#    'may',
#    "'wrapped",
#    'suicide',
#    "vest'",
#    'around',
#    'constitution',
#    'brexit',
#    'strategy'],
#   'negative'),
#  (["porsche's",
#    'sleek',
#    'chargers',
#    'will',
#    'power',
#    'evs',
#    'just',
#    'minutes'],
#   'neutral'),
#  (['learn',
#    'from',
#    'these',
#    'bugs.',
#    "don't",
#    'let',
#    'social',
#    'media',
#    'zombify',
#    'you'],
#   'neutral'),
#  (['citi:',
#    "here's",
#    'superior',
#    'strategy',
#    'profit',
#    'company',
#    'crush',
#    'earnings',
#    'expectation',
#    'long',
#    'even',
#    'report',
#    'result'],
#   'positive'),
#  (['the',
#    'entrepreneur',
#    'behind',
#    '10-year-old',
#    'company',
#    'shares',
#    'simple',
#    'strategy',
#    'that',
#    'will',
#    'get',
#    'you',
#    'over',
#    'any',
#    'creative',
#    'block'],
#   'positive'),
#  (['world',
#    'surf',
#    'league',
#    'announces',
#    'equal',
#    'prize',
#    'money',
#    'men',
#    'woman'],
#   'positive'),
#  (['trends', 'define', '2018', 'season'], 'neutral'),
#  (['twitter',
#    'hire',
#    'former',
#    'refinery29',
#    'coo',
#    'sarah',
#    'personette',
#    'head',
#    'client',
#    'solutions'],
#   'neutral'),
#  (['the',
#    'firestorm',
#    "hsbc's",
#    'investment',
#    'bank',
#    'escalating',
#    'bank',
#    'hit',
#    'back',
#    'internal',
#    'dissent'],
#   'neutral'),
#  (['here',
#    'speaker',
#    'far',
#    'techcrunch',
#    'startup',
#    'battlefield',
#    'mena',
#    '2018'],
#   'negative'),
#  (['pro14', 'talk', 'investor', 'exploiting', 'commercial', 'right'],
#   'negative'),
#  (['sadiq',
#    'khan',
#    'launch',
#    'anti-violence',
#    'plan',
#    'based',
#    'glasgow',
#    'unit'],
#   'neutral'),
#  (['used',
#    'car',
#    'site',
#    'vroom',
#    'raising',
#    '$70m',
#    'six',
#    'month',
#    'big',
#    'round',
#    'layoff'],
#   'neutral'),
#  (['jack',
#    'say',
#    'isn’t',
#    'retire',
#    'alibaba',
#    'but',
#    'planning',
#    'gradual',
#    'succession'],
#   'positive'),
#  (['bottas', 'take', 'pole', 'hamilton', 'russian'], 'neutral'),
#  (['tiger',
#    'woods',
#    'score',
#    'live:',
#    'pga',
#    'tour',
#    'championship',
#    'updates'],
#   'positive'),
#  (['new',
#    'york',
#    'today:',
#    'today’s',
#    'new',
#    'york',
#    'news:',
#    'gridlock',
#    'u.n.'],
#   'neutral'),
#  (['chirlane',
#    'mccray',
#    'endorses',
#    'zephyr',
#    'teachout',
#    'n.y.',
#    'attorney',
#    'general',
#    'race'],
#   'positive'),
#  (['beside',
#    'cynthia',
#    'nixon,',
#    'potential',
#    'first',
#    'lady',
#    'blaze',
#    'trail',
#    'her',
#    'own'],
#   'neutral'),
#  (['why', 'trump', 'worried', 'idlib?'], 'negative'),
#  (['this', 'week', 'the', 'business:', "streamer's", 'life', 'for'],
#   'neutral'),
#  (['rothy’s,',
#    'whose',
#    'ballet',
#    'flat',
#    'woman',
#    'already',
#    'everywhere,',
#    'launched',
#    'sneaker,'],
#   'neutral'),
#  (['xbox', 'one', 'getting', 'mouse', 'keyboard', 'support'], 'positive'),
#  (['facebook',
#    'unveils',
#    '“sapfix”',
#    'auto-debugger',
#    'chip',
#    'partner',
#    'like',
#    'intel'],
#   'positive'),
#  (['cleo,',
#    '‘digital',
#    'assistant’',
#    'replaces',
#    'banking',
#    'apps,',
#    'pick',
#    '$10m',
#    'series',
#    'led',
#    'balderton'],
#   'neutral'),
#  (['one', 'super', 'smash', 'bros.'], 'positive'),
#  (['world',
#    "warcraft's",
#    'new',
#    'warfronts',
#    "aren't",
#    'great,',
#    'but',
#    'the',
#    'loot',
#    'nice'],
#   'neutral'),
#  (['go-jek',
#    'plan',
#    'raise',
#    '$2b',
#    'southeast',
#    'asia',
#    'ride-hailing',
#    'battle'],
#   'negative'),
#  (['buy', 'ticket', 'concert', 'new', 'comcast', 'ticketmaster', 'feature'],
#   'neutral'),
#  (['insurtech',
#    'startup',
#    'setoo',
#    'close',
#    '$9.3m',
#    'series',
#    'kamet,',
#    'axa’s',
#    'accelerator'],
#   'neutral'),
#  (['coinbase', 'poaches', 'linkedin’s', 'head', 'data', 'michael'], 'neutral'),
#  (['data.world',
#    'raise',
#    '$12m',
#    'help',
#    'fortune',
#    '500',
#    'company',
#    'close',
#    'great',
#    'data',
#    'divide'],
#   'positive'),
#  (['block.party',
#    'raise',
#    '$10m,',
#    'adapt',
#    'settlers',
#    'catan',
#    'blockchain',
#    'game',
#    'console'],
#   'neutral'),
#  (['our', 'favorite', 'startup', 'urban-x’s', '4th', 'demo', 'day'],
#   'positive'),
#  (['sarah',
#    'taylor:',
#    'england',
#    'wicketkeeper',
#    'miss',
#    "women's",
#    'world',
#    't20'],
#   'neutral'),
#  (['coinbase',
#    'hire',
#    'fannie',
#    'mae',
#    'exec',
#    'brian',
#    'brooks',
#    'chief',
#    'legal',
#    'officer'],
#   'neutral'),
#  (['munich',
#    'buy',
#    'iot',
#    'middleware',
#    'startup,',
#    'relayr,',
#    'deal',
#    'worth',
#    '$300m'],
#   'positive'),
#  (['bipartisan', 'bill', 'seek', 'elevate', 'federal', 'cio', 'position'],
#   'neutral'),
#  (['this',
#    'fintech',
#    'business',
#    'pulled',
#    'off',
#    'major',
#    'company',
#    'pivot',
#    'believing',
#    'great',
#    'results'],
#   'positive'),
#  (['inbox', 'mess?', 'the', 'mailstrom', 'app', 'help', 'sale.'], 'neutral'),
#  (['hong',
#    'kong-based',
#    'onedegree',
#    'get',
#    '$25.5m',
#    'series',
#    'make',
#    'coverage',
#    'accessible,',
#    'starting',
#    'pet',
#    'insurance'],
#   'neutral'),
#  (['read',
#    'memo',
#    'goldman',
#    'sachs',
#    'sent',
#    'employee',
#    'announcing',
#    'big',
#    'management',
#    'overhaul',
#    '(gs)'],
#   'neutral'),
#  (['everything',
#    'need',
#    'know',
#    'facebook’s',
#    'data',
#    'breach',
#    'affecting',
#    '50m',
#    'user'],
#   'neutral'),
#  (['glasgow', 'school', 'art', 'accused', 'systemic', 'failing', 'fire'],
#   'negative'),
#  (['the', 'bright', 'future', 'cannabis', 'retail'], 'positive'),
#  (['women:',
#    "here's",
#    'how',
#    'overcome',
#    'your',
#    'fear',
#    'your',
#    'personal',
#    'brand'],
#   'negative'),
#  (['deep',
#    'dive:',
#    'how',
#    'cut',
#    'investment',
#    'risk',
#    'large-cap',
#    'dividend',
#    'stock'],
#   'negative'),
#  (['no,', 'day', 'not', '“micro-vacation”'], 'negative'),
#  (['this', 'scientist', 'think', 'need', 'move', 'people', 'away', 'coast'],
#   'neutral'),
#  (['trump',
#    'visit',
#    'hurricane-stricken',
#    'north',
#    'carolina,',
#    'death',
#    'toll'],
#   'negative'),
#  (['power', 'change', 'brain,', 'that’s', 'not', 'always', 'good', 'thing'],
#   'negative'),
#  (['second',
#    'ash',
#    'leak',
#    'reported',
#    'retired',
#    'duke',
#    'plant',
#    "florence's",
#    'wake'],
#   'negative'),
#  (['facebook',
#    'could',
#    'face',
#    '$1.63',
#    'billion',
#    'fine',
#    'latest',
#    'hack',
#    'under',
#    'gdpr'],
#   'positive'),
#  (['cryptocurrency',
#    'exchange',
#    'changelly',
#    'admits',
#    'steal',
#    'users’',
#    'monero',
#    '(if',
#    'wanted',
#    'to)'],
#   'negative'),
#  (['investment',
#    'chief',
#    'trillion-dollar',
#    'firm',
#    'break',
#    'down',
#    'costliest',
#    'mistake',
#    'american',
#    'investor',
#    'make',
#    'buying',
#    'country',
#    'avoid'],
#   'negative'),
#  (['income-share', 'agreement', 'novel', 'way', 'pay', 'tuition', 'fee'],
#   'positive'),
#  (['john',
#    'lewis',
#    'flap,',
#    'but',
#    "there's",
#    'need',
#    'undersell',
#    'nils',
#    'pratley'],
#   'negative'),
#  (['when',
#    'hurricane',
#    'hits,',
#    'having',
#    'dementia',
#    'adds',
#    'extra',
#    'challenge',
#    'and',
#    'even',
#    'more',
#    'risk'],
#   'negative'),
#  (['swiss',
#    'watchdog',
#    'rap',
#    'credit',
#    'suisse',
#    'anti-corruption',
#    'failing'],
#   'neutral'),
#  (['travel',
#    'snarled',
#    'flooding',
#    'carolinas',
#    'size',
#    "florence's",
#    'damage'],
#   'negative'),
#  (['how', 'companies', 'can', 'take', 'stand', 'against', 'bribery'],
#   'neutral'),
#  (['what', 'role', 'should', 'race', 'play', 'medicine?'], 'positive'),
#  (['d-id',
#    'launch',
#    'initial',
#    'product',
#    'customer',
#    'printing,',
#    'automotive',
#    'financial',
#    'service'],
#   'neutral'),
#  (['facebook', 'say', 'account', 'breached', 'attack'], 'negative'),
#  (['workflow',
#    'business',
#    'efficiency',
#    'strategies',
#    'you',
#    'ignore',
#    'your',
#    'peril'],
#   'negative'),
#  (["'massive",
#    "error':",
#    'farmer',
#    'say',
#    'post-brexit',
#    'funding',
#    'plan',
#    'risk',
#    'food',
#    'scare'],
#   'negative'),
#  (['hurricane',
#    'florence',
#    'updates:',
#    'storm',
#    'expected',
#    'gain',
#    'strength',
#    'tuesday'],
#   'positive'),
#  (['why', 'need', 'dynamic', 'secrets'], 'positive'),
#  (['key',
#    'words:',
#    'sec',
#    'embrace',
#    'risk,',
#    'say',
#    'commissioner',
#    'peirce'],
#   'neutral'),
#  (['what',
#    'come',
#    'next',
#    "facebook's",
#    'major',
#    'data',
#    'breach',
#    'yahoo',
#    'news'],
#   'neutral'),
#  (['justin', 'welby', 'suggests', 'universal', 'credit', 'rollout', 'halted'],
#   'positive'),
#  (['u.s.', 'auto', 'sector', 'output', 'boost', 'industrial', 'production'],
#   'positive'),
#  (['why',
#    'small',
#    'businesses',
#    'need',
#    'vigilant',
#    'about',
#    'iot',
#    'security',
#    'too'],
#   'positive'),
#  (['lehman', 'brothers', 'year', 'panel', 'nicky', 'morgan', 'others'],
#   'neutral'),
#  (['danske', 'bank', 'whistleblower', 'ex-baltics', 'trading', 'head'],
#   'neutral'),
#  (['spat', 'spanish', 'soccer', 'playing', 'daytime', 'heat'], 'positive'),
#  (['obesity',
#    'alters',
#    'airway',
#    'muscle',
#    'function,',
#    'increase',
#    'asthma',
#    'risk'],
#   'negative'),
#  (['major', 'flooding', 'lingering', 'week', 'florence', 'fox', 'news'],
#   'neutral'),
#  (['carolinas', 'brace', 'day', 'flood', "florence's", 'deluge'], 'neutral'),
#  (["trump's",
#    'methane',
#    'rule',
#    'rollback',
#    'will',
#    'make',
#    'more',
#    'people',
#    'sick'],
#   'negative'),
#  (['ford', "'must", 'execute', 'significant', 'structural', "change'", '(f)'],
#   'positive'),
#  (['report:',
#    "google's",
#    'chinese',
#    'search',
#    'prototype',
#    'logs',
#    'phone',
#    'numbers,',
#    'hides',
#    'unapproved',
#    'pollution',
#    'data'],
#   'negative'),
#  (['hundreds',
#    'confirmed',
#    'dead',
#    'indonesian',
#    'tsunami,',
#    'with',
#    'officials',
#    'warning',
#    'toll',
#    'will',
#    'rise'],
#   'negative'),
#  (['thailand', 'becoming', 'critical', 'country', 'blockchain'], 'negative'),
#  (['how', 'make', 'leap', 'ceo', 'entrepreneur'], 'neutral'),
#  (['fosscon', '2018:', 'developing', 'freedombox'], 'neutral'),
#  (['the',
#    'fed:',
#    'there’s',
#    'risk',
#    'fed',
#    'stock',
#    'market',
#    'aren’t',
#    'sync,',
#    'former',
#    'vice',
#    'chairman',
#    'warns'],
#   'negative'),
#  (['podcast', '#438:', 'developing', 'real-world', 'situational', 'awareness'],
#   'neutral'),
#  (['u.s.',
#    'canada',
#    'end',
#    'friday',
#    'without',
#    'reaching',
#    'deal',
#    'new',
#    'nafta'],
#   'neutral'),
#  (['6.3-magnitude',
#    'earthquake',
#    'rattles',
#    'ecuador,',
#    'toppling',
#    'power',
#    'lines',
#    'injuring',
#    'one'],
#   'neutral'),
#  (['outside',
#    'box:',
#    'ex-citimortgage',
#    'ceo:',
#    'thing',
#    'learned',
#    '2008',
#    'great',
#    'financial',
#    'crisis'],
#   'neutral'),
#  (['california',
#    'wildfire',
#    'map:',
#    'delta',
#    'fire',
#    'closes',
#    'down',
#    'miles',
#    'i-5,',
#    'showing',
#    'sign',
#    'slowing'],
#   'negative'),
#  (['deutsche',
#    'bank:',
#    'these',
#    'radical',
#    'idea',
#    'could',
#    'give',
#    '$150',
#    'billion',
#    'auditing',
#    'industry',
#    'much-needed',
#    'shake-up'],
#   'neutral'),
#  (['predicting', 'flood', 'risk', 'better'], 'positive'),
#  (['hurricane',
#    'florence:',
#    "'extremely",
#    "dangerous'",
#    'storm',
#    'threatens',
#    'east',
#    'coast'],
#   'negative'),
#  (['where', 'hurricane', 'florence', 'hit?'], 'neutral'),
#  (['bournemouth', 'nightclub', 'evacuated', "'teargas'", 'released'],
#   'neutral'),
#  (['surf',
#    'condition',
#    'growing',
#    'dangerous',
#    'along',
#    'volusia,',
#    'flagler',
#    'coast',
#    'hurricane',
#    'florence',
#    'strengthens',
#    'daytona',
#    'beach',
#    'news-journal'],
#   'neutral'),
#  (['south',
#    'carolina',
#    'governor',
#    'declares',
#    'state',
#    'emergency',
#    'officials',
#    'expect',
#    'tropical',
#    'storm',
#    'florence',
#    'strengthen'],
#   'neutral'),
#  (['s&p', '500,', 'dow', 'rising', 'treasury', 'yield', 'boost', 'bank'],
#   'positive'),
#  (['thousands',
#    'told',
#    'flee',
#    'florence-triggered',
#    'flood',
#    'wash',
#    'south',
#    'carolina'],
#   'neutral'),
#  (['company',
#    'veteran',
#    'named',
#    'airbus',
#    'sale',
#    'chief',
#    'ex-rolls',
#    'executive',
#    'quits'],
#   'neutral'),
#  (['indycar',
#    'driver',
#    'calls',
#    'union:',
#    "'you",
#    'shouldn’t',
#    'have',
#    'risk',
#    'your',
#    'life',
#    "free'"],
#   'positive'),
#  (['asian',
#    'stocks,',
#    'u.s.',
#    'treasury',
#    'yield',
#    'climb',
#    'trade',
#    'row',
#    'fails',
#    'dent',
#    'confidence'],
#   'positive'),
#  (['asia',
#    'rise',
#    'stimulus',
#    'hope',
#    'lift',
#    'chinese',
#    'stock',
#    'amid',
#    'trade',
#    'row'],
#   'positive'),
#  (['danske',
#    'bank',
#    'ceo',
#    'quits',
#    '$234',
#    'billion',
#    'money',
#    'laundering',
#    'scandal'],
#   'negative'),
#  (['carolinas', 'deluged', 'flood', 'florence', 'move'], 'neutral'),
#  (['floodwaters', 'rise,', 'florence', 'devastates', 'north', 'carolina'],
#   'negative'),
#  (['why', 'hard', 'climb', 'career', 'ladder', 'charity?'], 'positive'),
#  (['browser', 'extensions:', 'are', 'they', 'worth', 'risk?'], 'neutral'),
#  (['why', 'add', 'itil', 'certification', 'resume'], 'neutral'),
#  (['hurricanes',
#    'are',
#    'relapse',
#    'danger',
#    'for',
#    'drug',
#    'users,',
#    'but',
#    'experts',
#    'have',
#    'plan',
#    'for',
#    'florence'],
#   'negative'),
#  (['latest:',
#    'florence',
#    'continues',
#    'torment',
#    'flooding,',
#    'power',
#    'outage',
#    'wral.com'],
#   'neutral'),
#  (['snap', 'let', 'publisher', 'curate', 'user', 'post', '(snap)'], 'neutral'),
#  (['massachusetts',
#    'issued',
#    '1,905',
#    'license',
#    'dead',
#    "people's",
#    'names,',
#    'contested',
#    'state',
#    'audit',
#    'find'],
#   'negative'),
#  (['what',
#    'need',
#    'know',
#    'flood',
#    'insurance',
#    'hurricane',
#    'florence',
#    'dump',
#    'rain',
#    'north',
#    'carolina'],
#   'negative'),
#  (['structured', 'approach', 'operational', 'risk', 'management'], 'negative'),
#  (['hurricane',
#    'florence',
#    'barreling',
#    'toward',
#    'carolinas,',
#    'least',
#    'million',
#    'people',
#    'ordered',
#    'evacuate',
#    'area',
#    'could',
#    'get',
#    'hit'],
#   'neutral'),
#  (['california',
#    'governor',
#    'sign',
#    'country’s',
#    'toughest',
#    'net',
#    'neutrality',
#    'law'],
#   'neutral'),
#  (['higher',
#    'rainfall',
#    'estimates',
#    'could',
#    'alter',
#    'construction',
#    'plans'],
#   'neutral'),
#  (['ashley',
#    'face',
#    'potential',
#    'revolt',
#    'sports',
#    'direct',
#    'annual',
#    'meeting'],
#   'neutral'),
#  (['nhs', 'accused', 'racial', 'discrimination', 'pay', 'senior', 'doctor'],
#   'negative'),
#  (['why', 'bcc-ing', 'boss', 'bad', 'practice'], 'negative'),
#  (['appetite',
#    'shark',
#    'fin',
#    'soup',
#    'serious',
#    'risk',
#    'threatened',
#    'shark'],
#   'negative'),
#  (['playmaker', 'pickford', 'recognises', 'limit', 'footballing', 'ability'],
#   'positive'),
#  (['ibm',
#    'mission',
#    'defend',
#    '‘street',
#    'cred’',
#    'upstart',
#    'trying',
#    'muscle',
#    'turf',
#    '(ibm,',
#    'amzn,',
#    'goog,',
#    'googl,',
#    'fb)'],
#   'neutral'),
#  (["america's", 'health', 'care', 'system', 'could', 'much', 'better'],
#   'positive'),
#  (['relaxed',
#    'environmental',
#    'regulation',
#    'heighten',
#    'risk',
#    'natural',
#    'disaster'],
#   'neutral'),
#  (['future', 'tidal', 'wetland', 'depends', 'coastal', 'management'],
#   'neutral'),
#  (['future', 'tidal', 'wetland', 'depends', 'coastal', 'management'],
#   'neutral'),
#  (['florence',
#    'looms,',
#    'trump',
#    'say',
#    'response',
#    "'incredibly",
#    "successful'",
#    'last',
#    'year',
#    'puerto',
#    'rico',
#    'washington',
#    'post'],
#   'positive'),
#  (['doj',
#    'probe',
#    'into',
#    "elon's",
#    'tweets',
#    'could',
#    'spell',
#    'yet',
#    'more',
#    'trouble',
#    'tesla'],
#   'negative'),
#  (['why', 'trump', 'tacitly', 'supporting', 'corruption', 'guatemala?'],
#   'positive'),
#  (['lehman', 'failed', 'good', 'reasons'], 'neutral'),
#  (['hospital',
#    'trust',
#    'criticised',
#    'death',
#    'woman',
#    'drank',
#    'floor',
#    'cleaner'],
#   'negative'),
#  (['trump', 'ceo,', 'board', 'would', 'fired'], 'negative'),
#  (['good', 'governance', 'migratory', 'specie'], 'positive'),
#  (['jack',
#    'say',
#    'isn’t',
#    'retire',
#    'alibaba',
#    'but',
#    'planning',
#    'gradual',
#    'succession'],
#   'positive'),
#  (['pension', 'fund', 'oppose', 'ryanair', 'annual', 'meeting'], 'neutral'),
#  (['ashley',
#    'face',
#    'potential',
#    'revolt',
#    'sports',
#    'direct',
#    'annual',
#    'meeting'],
#   'neutral'),
#  (['alibaba',
#    'announces',
#    'ceo',
#    'daniel',
#    'zhang',
#    'succeed',
#    'jack',
#    'chairman',
#    'next',
#    'year'],
#   'positive'),
#  (['mexican',
#    'force',
#    'seize',
#    'control',
#    'entire',
#    'acapulco',
#    'police',
#    'department'],
#   'neutral'),
#  (['ryanair',
#    'face',
#    'growing',
#    'backlash',
#    'annual',
#    'shareholder',
#    'meeting'],
#   'neutral'),
#  (['plutocracy', 'still', 'bad'], 'negative'),
#  (['under-fire',
#    'sports',
#    'direct',
#    'chairman',
#    'keith',
#    'hellawell',
#    'step',
#    'down'],
#   'neutral'),
#  (['jack',
#    'step',
#    'down',
#    'chairman',
#    'chinese',
#    'e-commerce',
#    'giant',
#    'alibaba',
#    'september',
#    '2019'],
#   'neutral'),
#  (['elon',
#    'musk',
#    'resigns',
#    'tesla',
#    'chairman,',
#    'must',
#    'pay',
#    '$20',
#    'million',
#    'fine',
#    'sec',
#    'settlement',
#    'over',
#    'catastrophic',
#    "'420'",
#    'tweet'],
#   'negative'),
#  (['google:', 'amp', 'use', '‘consensus-seeking’', 'governance', 'model'],
#   'neutral'),
#  (['python',
#    'programming',
#    'language',
#    'ditches',
#    "'master-slave'",
#    'terms,',
#    'pissing',
#    'off',
#    'some'],
#   'negative'),
#  (['could',
#    '‘community',
#    'apps’',
#    'built',
#    'blockchain',
#    'solve',
#    'facebook’s',
#    'existential',
#    'crisis?'],
#   'negative'),
#  (['ousting',
#    'elon',
#    'musk',
#    'from',
#    'tesla',
#    'will',
#    'take',
#    'more',
#    'than',
#    'lawsuits',
#    'twitter',
#    'fights'],
#   'negative'),
#  (['sport’s',
#    'desperation',
#    'rich',
#    'reinvention',
#    'increasingly',
#    'offputting',
#    'emma',
#    'john'],
#   'neutral'),
#  (['putting',
#    'worker',
#    'board',
#    'bitter',
#    'but',
#    'necessary',
#    'pill',
#    'nils',
#    'pratley'],
#   'negative'),
#  (['google', 'giving', 'some', 'control', 'amp', 'format'], 'positive'),
#  (["china's",
#    'leaders',
#    'soften',
#    'their',
#    'stance',
#    'ai,',
#    'say',
#    'they',
#    'will',
#    'sharing',
#    'their',
#    'findings',
#    'with',
#    'other',
#    'countries'],
#   'positive'),
#  (['marshall',
#    'islands',
#    'warned',
#    'against',
#    'adopting',
#    'digital',
#    'currency'],
#   'negative'),
#  (['google', 'moving', 'amp', 'open', 'governace', 'model'], 'neutral'),
#  (['nhs', 'bos', 'call', 'superdrug', 'screen', 'botox', 'customer'],
#   'neutral'),
#  (['royal', 'mail', 'chair', 'resigns', 'amid', 'boardroom', 'revolt'],
#   'negative'),
#  (['editorial', 'expression', 'concern'], 'neutral'),
#  (['earth',
#    'scientists',
#    'propose',
#    'giant',
#    'wall',
#    'stop',
#    'antarctic',
#    'ice',
#    'sheet',
#    'from',
#    'collapsing'],
#   'negative'),
#  (['clean',
#    'energy',
#    'boom',
#    'could',
#    'fuel',
#    'one',
#    "world's",
#    'dirtiest',
#    'industries'],
#   'neutral'),
#  (['irishman', 'arrested', 'chasing', 'missed', 'flight', 'foot', 'takeoff'],
#   'negative'),
#  (['hysterical',
#    'world,',
#    'wikipedia',
#    'ray',
#    'light',
#    'that’s',
#    'truth',
#    'john',
#    'naughton'],
#   'positive'),
#  (['$10',
#    'billion',
#    'marijuana',
#    'producer',
#    'spun',
#    'venture',
#    'arm',
#    'hope',
#    'become',
#    "'google",
#    'ventures',
#    "cannabis'",
#    '(riv)'],
#   'positive'),
#  (['thing', 'tech', 'need', 'know', 'today', '(goog)'], 'neutral'),
#  (['companies',
#    'sticking',
#    'practice',
#    'warren',
#    'buffett',
#    'business',
#    'titan',
#    'warn',
#    'damaging',
#    'economy'],
#   'negative'),
#  (['top', 'priority', 'transparency,', 'say', 'naidu'], 'positive'),
#  (['equifax',
#    'slapped',
#    'uk’s',
#    'maximum',
#    'penalty',
#    '2017',
#    'data',
#    'breach'],
#   'negative'),
#  (['cuomo-nixon',
#    'showdown',
#    'new',
#    'york',
#    "governor's",
#    'race',
#    'go',
#    'voter'],
#   'neutral'),
#  (['cvc',
#    'ownership',
#    'serve',
#    'warning',
#    'premiership',
#    'rugby',
#    'giles',
#    'richards'],
#   'negative'),
#  (['our',
#    'political',
#    'upheaval',
#    "wasn't",
#    'caused',
#    'mob',
#    'rule,',
#    'but',
#    'institution',
#    'designed',
#    'preserve',
#    'elite',
#    'oversight'],
#   'neutral'),
#  (['bonus', 'bonanza', 'university', 'campus', 'strip-club', 'scandal'],
#   'neutral'),
#  (['alibaba’s',
#    'jack',
#    'says',
#    'will',
#    'step',
#    'down',
#    'chairman',
#    'september',
#    'next',
#    'year'],
#   'neutral'),
#  (['ryanair',
#    'chair',
#    'survives',
#    'shareholder',
#    'revolt',
#    'but',
#    'investor',
#    'want',
#    'change'],
#   'neutral'),
#  (['erika',
#    'alexander',
#    'using',
#    'blockchain',
#    'make',
#    'journalism',
#    'inclusive'],
#   'neutral'),
#  (['video',
#    'show',
#    'aftermath',
#    'brazil',
#    'museum',
#    'fire,',
#    'almost',
#    'nothing',
#    'left',
#    'but',
#    'ancient',
#    'meteorite'],
#   'neutral'),
#  (['brazil’s',
#    'far-right',
#    'vice',
#    'presidential',
#    'candidate',
#    'sees',
#    'scenario',
#    'for',
#    'military',
#    'rule'],
#   'neutral'),
#  (['trader',
#    'guilty',
#    "uk's",
#    'biggest',
#    'fraud',
#    'detained',
#    'prior',
#    'deportation'],
#   'negative'),
#  (['aston',
#    'martin',
#    'name',
#    'first',
#    'female',
#    'chair',
#    'prepares',
#    '£5bn',
#    'float'],
#   'neutral'),
#  (['blackrock',
#    'voted',
#    'replace',
#    "tesla's",
#    'elon',
#    'musk',
#    'independent',
#    'chairman'],
#   'neutral'),
#  (['china',
#    'developed',
#    "world's",
#    'largest',
#    'flying',
#    'boat,',
#    'could',
#    'used',
#    'ferry',
#    'troop',
#    'south',
#    'china',
#    'sea'],
#   'neutral'),
#  (['the', 'collapse', 'eth', 'inevitable'], 'negative'),
#  (['how', 'make', 'technology', 'force', 'good'], 'positive'),
#  (['san',
#    'francisco',
#    'struggle',
#    'wealth-poverty',
#    'disparity',
#    'visible',
#    'streets...'],
#   'negative'),
#  (['blackrock',
#    'voted',
#    'replace',
#    "tesla's",
#    'musk',
#    'independent',
#    'chairman'],
#   'neutral'),
#  (['edwin',
#    'moses:',
#    'wada',
#    'must',
#    'cut',
#    'tie',
#    'ioc',
#    'regain',
#    'trust',
#    'sport'],
#   'positive'),
#  (['fbi',
#    'face',
#    'lawsuit',
#    'putting',
#    'people',
#    'no-fly',
#    'list',
#    'refusing',
#    'inform',
#    'friend'],
#   'neutral'),
#  (['icici', 'securities', 'jump', 'kochhar', 'stay', 'board'], 'positive'),
#  (['anniversary',
#    'sept.',
#    'attacks,',
#    'terrorist',
#    'readying',
#    'attack',
#    'again:',
#    '9/11',
#    'commissioner'],
#   'negative'),
#  (['how', 'south', 'africa’s', '‘ramaphoria’', 'turned', '‘ramageddon’'],
#   'neutral'),
#  (['brexit', 'buoyancy', 'bypass', 'brussels', 'still', 'unsure', 'deal'],
#   'negative'),
#  (['under',
#    'fire',
#    'danske',
#    'bank',
#    'face',
#    'fresh',
#    'money',
#    'laundering',
#    'inquiry'],
#   'neutral'),
#  (['sec', 'sue', 'musk', 'fraud,', 'seek', 'remove', 'tesla'], 'negative'),
#  (["tesla's",
#    'musk',
#    'could',
#    'settle',
#    'sec',
#    'suit',
#    'but',
#    'ready',
#    'fight:',
#    'source'],
#   'neutral'),
#  (['u.s.', 'regulator', 'sue', 'musk', 'fraud,', 'seek', 'remove', 'tesla'],
#   'negative'),
#  (['how', 'business', 'need', 'take', 'charge', 'going', 'green'], 'neutral'),
#  (['big', 'really', 'beautiful?', 'the', 'limit', 'pension', 'consolidation'],
#   'positive'),
#  (['the',
#    'ratings',
#    'game:',
#    'why',
#    'snap’s',
#    'executive',
#    'exodus',
#    'could',
#    'actually',
#    'positive'],
#   'positive'),
#  (['elon',
#    'musk',
#    'step',
#    'down',
#    'tesla',
#    'chairman',
#    'following',
#    'deal',
#    'regulator'],
#   'neutral'),
#  (['bjp', 'party', 'heart', 'governance', 'propaganda'], 'neutral'),
#  (['elon',
#    'musk',
#    'steps',
#    'down',
#    'tesla',
#    'chairman',
#    '$40',
#    'million',
#    'sec',
#    'settlement'],
#   'neutral'),
#  (['you',
#    'may',
#    'laugh,',
#    'but',
#    'trump',
#    'point',
#    'globalisation',
#    'larry',
#    'elliott'],
#   'positive'),
#  (['musk', 'step', 'down', 'tesla', 'chairman', 'sec', 'settlement'],
#   'neutral'),
#  (['goldman',
#    'sachs',
#    'ditching',
#    'near-term',
#    'plan',
#    'open',
#    'bitcoin',
#    'trading',
#    'desk',
#    'instead',
#    'focusing',
#    'key',
#    'business',
#    'driving',
#    'wall',
#    'street',
#    'investment',
#    'crypto'],
#   'neutral'),
#  (['rbi',
#    'governor',
#    'urijit',
#    'patel',
#    'explains',
#    'preventive',
#    'vigilance',
#    'work',
#    'better',
#    'punitive',
#    'vigilance',
#    'public',
#    'sector'],
#   'neutral'),
#  (['google', 'creates', 'new', 'governance', 'model', 'amp'], 'positive'),
#  (['blueprint',
#    'future',
#    'success',
#    'women’s',
#    'pro',
#    'cycling',
#    'stephanie',
#    'constand'],
#   'positive'),
#  (['sh.',
#    'ravi',
#    'shankar',
#    'prasad',
#    'launch',
#    'centre',
#    'excellence',
#    'data',
#    'analytics',
#    'digivaarta'],
#   'positive'),
#  (['jehovah’s', 'witness', 'girl', 'could', 'receive', 'blood', 'childbirth'],
#   'neutral'),
#  (['rachael',
#    'burford',
#    'expecting',
#    'bigger',
#    'thing',
#    'harlequins',
#    'premier',
#    '15'],
#   'neutral'),
#  (['how',
#    'deliver',
#    'translational',
#    'data-science',
#    'benefit',
#    'science',
#    'society'],
#   'positive'),
#  (['what',
#    'jack',
#    'taught',
#    'about',
#    'good',
#    'corporate',
#    'governance',
#    'this',
#    'week'],
#   'positive'),
#  (['how',
#    'deliver',
#    'translational',
#    'data-science',
#    'benefit',
#    'science',
#    'society'],
#   'positive'),
#  (['reality', 'check:', 'how', 'brexit', 'preparation', 'getting', 'on?'],
#   'neutral'),
#  (['modi', 'government', 'face', 'heat', 'fuel', 'fury'], 'negative'),
#  (['danger',
#    'zone:',
#    'managers',
#    'who',
#    'get',
#    'away',
#    'bad',
#    'corporate',
#    'governance'],
#   'negative'),
#  (["japan's",
#    '"show',
#    'money"',
#    'corporate',
#    'governance:',
#    'renewed',
#    'surge'],
#   'neutral'),
#  (['could', 'devops', 'exist', 'without', 'cloud', 'models?'], 'neutral'),
#  (['environmental',
#    'conservation',
#    'corporate',
#    'governance',
#    'the',
#    'forefront',
#    'nordic',
#    'investment',
#    'trends'],
#   'neutral'),
#  (['the',
#    'moral',
#    'law',
#    'within:',
#    'the',
#    'scientific',
#    'case',
#    'for',
#    'self-governance'],
#   'neutral'),
#  (['cvc’s',
#    'premiership',
#    'bid',
#    'may',
#    'rejected',
#    'but',
#    'could',
#    'signal',
#    'change',
#    'the',
#    'breakdown'],
#   'negative'),
#  (['rite',
#    'aid',
#    'shakes',
#    'governance,',
#    'strips',
#    'ceo',
#    'chairman',
#    'role'],
#   'neutral'),
#  (['cognizant', 'name', 'michael', 'patsalos-fox', 'new', 'chairman', 'board'],
#   'neutral'),
#  (["'it's",
#    "revolution':",
#    'indian',
#    'official',
#    'deliver',
#    'public',
#    'service',
#    "people's",
#    'doorstep'],
#   'neutral'),
#  (['google', 'announces', 'new', 'governance', 'model', 'amp'], 'neutral'),
#  (["'this",
#    'behaviour',
#    'must',
#    "stop':",
#    'california',
#    'may',
#    'soon',
#    'require',
#    'woman',
#    'board'],
#   'neutral'),
#  (['supertyphoon',
#    'mangkhut',
#    'hammers',
#    'philippines,',
#    'causing',
#    'many',
#    'deaths',
#    'wall',
#    'street',
#    'journal'],
#   'neutral'),
#  (['governance:', 'research', 'agenda'], 'neutral'),
#  (["tesla's",
#    'elon',
#    'musk',
#    'settle',
#    'sec,',
#    'paying',
#    '$20',
#    'million',
#    'fine',
#    'resigning',
#    'board',
#    'chairman',
#    'washington',
#    'post'],
#   'neutral'),
#  (['keith',
#    "hellawell's",
#    'sports',
#    'direct',
#    'reign',
#    'come',
#    'chaotic',
#    'end',
#    'nils',
#    'pratley'],
#   'negative'),
#  (['edible', 'innovation:', 'all', 'bamboo,', 'all', 'sustainability!'],
#   'positive'),
#  (['grace',
#    'notes:',
#    'from',
#    '1993',
#    'vow',
#    '320,000',
#    'reusable',
#    'water',
#    'bottles',
#    'every',
#    'new',
#    'york',
#    'high',
#    'schooler'],
#   'positive'),
#  (['moviepass', 'competitor', 'sinemia', 'launch', 'unlimited', 'plan'],
#   'neutral'),
#  (["apple's",
#    'claim',
#    'recycling',
#    'sustainability',
#    'kinda',
#    'entirely',
#    'nonsense'],
#   'negative'),
#  (['lyft', 'hire', 'yet', 'another', 'ex-tesla', 'employee'], 'neutral'),
#  (['starbucks',
#    'making',
#    'store',
#    'sustainable–and',
#    'want',
#    'help',
#    'others'],
#   'positive'),
#  (['profits',
#    'planet:',
#    'big',
#    'business',
#    'environment',
#    'get',
#    'along?',
#    'yossi',
#    'sheffi'],
#   'positive'),
#  (['healthy',
#    'diets',
#    'protect',
#    'the',
#    'planet?',
#    'the',
#    'u.n.',
#    'meets,',
#    'focus',
#    'sustainability'],
#   'positive'),
#  (['behind', 'scenes', 'look', "rothy's", 'new', 'sneaker'], 'neutral'),
#  (['led',
#    'group',
#    'disloyal',
#    'new',
#    'york',
#    'democrats.',
#    'will',
#    'cost',
#    'him',
#    'his',
#    'seat?'],
#   'neutral'),
#  (['switzerland',
#    'considers',
#    'tighter',
#    'rule',
#    'sustainable',
#    "'fair",
#    "food'"],
#   'positive'),
#  (['new',
#    'use',
#    'google',
#    'maps:',
#    'calculating',
#    'city’s',
#    'carbon',
#    'footprint'],
#   'neutral'),
#  (['you', "don't", 'have', 'elon', 'musk', 'make', 'difference'], 'neutral'),
#  (['fresh', 'meat:', 'eat', 'vegan', 'student', 'budget'], 'neutral'),
#  (['lyft:', '“we', 'fully', 'carbon-neutral', 'company”'], 'neutral'),
#  (['best', 'food', 'get', 'delivered'], 'positive'),
#  (['taylor',
#    'guitars',
#    'took',
#    'big',
#    'risk',
#    'investing',
#    'african',
#    'sawmill',
#    'but',
#    'according',
#    'ceo,',
#    'great',
#    'move',
#    'company'],
#   'positive'),
#  (['vola', 'celebrates', '50th', 'birthday', 'series', 'short', 'film'],
#   'positive'),
#  (['global',
#    'soft',
#    'drink',
#    'firm',
#    'back',
#    'plan',
#    'eliminate',
#    'packaging',
#    'waste'],
#   'negative'),
#  (['world',
#    'must',
#    'march',
#    'union',
#    'secure',
# ...
#    'all-time',
#    'low',
#    'search',
#    'acquisition',
#    'vurb’s',
#    'ceo',
#    'bail'],
#   'neutral'),
#  (['tesla', 'set', 'open', 'lowest', 'price', 'since', 'june', '(tsla)'],
#   'negative'),
#  (['deal:', 'let', "eufy's", '£168', 'robovac', 'keep', 'floor', 'clean'],
#   'positive'),
#  (['center', 'kavanaugh', 'accusations:', 'heavy', 'drinking'], 'negative'),
#  (['dominic',
#    'raab',
#    'say',
#    'british',
#    'firm',
#    'using',
#    'brexit',
#    "'easy'",
#    'excuse',
#    'poor',
#    'result'],
#   'negative'),
#  (['tweeters',
#    'stir',
#    'over',
#    'donald',
#    "trump's",
#    'claim',
#    "'fell",
#    "asleep'",
#    'barack',
#    "obama's",
#    'speech'],
#   'neutral'),
#  (['obesity', "'to", 'linked', 'female', "cancers'", 'smoking'], 'neutral'),
#  (['five', 'reason', 'john', 'lewis', 'profit', 'dived'], 'positive'),
#  (['unexpected', 'thing', 'happen', 'body', 'pregnancy'], 'neutral'),
#  (['police', 'question', 'man', 'centre', 'salisbury', 'scare'], 'negative'),
#  (['give',
#    'boot:',
#    '$530',
#    'distressed',
#    'sneaker',
#    'accused',
#    'fetishizing',
#    'poverty'],
#   'negative'),
#  (['at-risk', 'child', "'left", 'fend', "themselves'", 'cut', 'service'],
#   'negative'),
#  (['raul', 'jimenez', 'goal', 'help', 'wolves', 'beat', 'burnley'],
#   'positive'),
#  (['yemen',
#    'conflict:',
#    'million',
#    'child',
#    'face',
#    'famine,',
#    'ngo',
#    'warns'],
#   'negative'),
#  (['the',
#    'number',
#    'youth',
#    'juvenile',
#    'detention',
#    'california',
#    'has',
#    'quietly',
#    'plummeted'],
#   'negative'),
#  (['key', 'house', 'fraser', 'supplier', 'pull', 'jaeger', 'brand'],
#   'neutral'),
#  (['how', 'sleep', 'after', 'wisdom', 'teeth', 'removal'], 'positive'),
#  (['way', 'adult', 'fun', 'disney', 'cruise'], 'positive'),
#  (['grand',
#    'designs',
#    'review:',
#    'kevin',
#    'mccloud',
#    'standing',
#    'front',
#    'tiny',
#    'castle?',
#    'smell',
#    'trouble'],
#   'neutral'),
#  (['world',
#    'health',
#    'organization',
#    'study',
#    'finds',
#    'alcohol',
#    'responsible',
#    'five',
#    'percent',
#    'deaths',
#    'worldwide'],
#   'positive'),
#  (['volcanic',
#    'explosion',
#    'shut',
#    'down',
#    'national',
#    'park.',
#    'it’s',
#    'reopen',
#    'without',
#    'lava.'],
#   'neutral'),
#  (['dandruff',
#    'scratching',
#    'new',
#    'asmr',
#    'trend',
#    "can't",
#    'believe',
#    'love'],
#   'negative'),
#  (['the', 'tide', 'high,', 'and', 'this', 'clock', 'lets', 'you', 'know'],
#   'neutral'),
#  (['reason', 'focus', 'attention', 'current', 'product', 'offering'],
#   'neutral'),
#  (['ashes',
#    'ashes:',
#    'britons',
#    'follow',
#    'david',
#    'bowie',
#    'choosing',
#    'direct',
#    'cremation'],
#   'neutral'),
#  (['the',
#    'pretend',
#    'billionaire',
#    'who',
#    'threw',
#    'insane',
#    'parties',
#    'celebs',
#    'then',
#    'vanished'],
#   'neutral'),
#  (['apple', 'report', 'first', 'self-driving', 'car', 'crash'], 'negative'),
#  (['model',
#    'crash',
#    'tests',
#    'hammer',
#    'home',
#    "tesla's",
#    'safety',
#    'excellence'],
#   'positive'),
#  (['watch', 'tesla', 'model', 'earned', 'nhtsa’s', 'top', 'safety', 'rating'],
#   'positive'),
#  (['kristina',
#    'vogel',
#    'crash',
#    'left',
#    'paralysed:',
#    "'i've",
#    'learned',
#    'cry',
#    'bad',
#    "is'"],
#   'negative'),
#  (['the', 'silence', 'after', 'hit-and-run'], 'neutral'),
#  (['how',
#    'robyn,',
#    'pop’s',
#    'glittery',
#    'rebel,',
#    'danced',
#    'her',
#    'way',
#    'back',
#    'from',
#    'darkness'],
#   'negative'),
#  (['uber',
#    'get',
#    'better',
#    'safety',
#    'ride',
#    'check',
#    'address',
#    'anonymization'],
#   'positive'),
#  (['goldman',
#    'cto:',
#    'story',
#    'dropping',
#    'bitcoin',
#    'trading',
#    '‘fake',
#    'news’'],
#   'neutral'),
#  (['dutch', 'rail', 'crash:', 'four', 'child', 'killed', 'cargo', 'bike'],
#   'negative'),
#  (['crashed', 'bus', 'may', 'holding', 'building'], 'neutral'),
#  (['killed', 'wrong-way', 'crash', 'indiana', 'toll', 'road', 'wls-tv'],
#   'negative'),
#  (['uber', 'hope', 'new', 'font', 'symbolize', 'turnaround'], 'positive'),
#  (["arm's", 'latest', 'chip', 'first', 'one', 'built', 'self-driving', 'car'],
#   'neutral'),
#  (['uber',
#    'ceo:',
#    'plan',
#    'sell',
#    'self-driving',
#    'car',
#    'unit',
#    '‘for',
#    'now’'],
#   'negative'),
#  (['olympic',
#    'champion',
#    'cyclist',
#    'kristina',
#    'vogel',
#    'paralysed',
#    'training',
#    'crash'],
#   'positive'),
#  (['tesla', 'model', 'earns', 'five-star', 'nhtsa', 'crash', 'rating'],
#   'negative'),
#  (['bear',
#    'photobombs',
#    "couple's",
#    'wedding',
#    'photo',
#    'best',
#    'possible',
#    'way'],
#   'positive'),
#  (['two',
#    'killed',
#    'jet',
#    'snap',
#    'half',
#    'failed',
#    'landing',
#    'yahoo',
#    'news'],
#   'negative'),
#  (['woman',
#    'found',
#    'dead,',
#    'three',
#    'people',
#    'missing',
#    'arizona',
#    'boat',
#    'crash'],
#   'negative'),
#  (['dismisses',
#    'gordon',
#    "brown's",
#    'warning',
#    "'sleepwalking",
#    'financial',
#    "crisis'"],
#   'negative'),
#  (['uber',
#    'investing',
#    '$150m',
#    'toronto',
#    'expand',
#    'self-driving',
#    'car',
#    'effort'],
#   'positive'),
#  (['top', 'gear:', 'bbc', 'behemoth', 'became', 'car', 'crash'], 'negative'),
#  (['all',
#    'passengers',
#    'survive',
#    'plane',
#    'crash',
#    'micronesia:',
#    "'it",
#    'was',
#    "surreal'"],
#   'negative'),
#  (['trump', 'mark', '9/11', 'anniversary', 'pennsylvania', 'memorial'],
#   'neutral'),
#  (['opec', 'signals', 'rush', 'increase', 'oil', 'output'], 'neutral'),
#  (['bin', 'laden', 'business', 'grew', 'humble', 'beginning'], 'neutral'),
#  (['this',
#    '$25',
#    'dash',
#    'cam',
#    'might',
#    'best',
#    'car',
#    'accessory',
#    'purchase',
#    'yet'],
#   'positive'),
#  (['unusual', 'car', 'crash', 'atlanta'], 'negative'),
#  (['natural', 'weight-loss', 'remedy', 'work'], 'positive'),
#  (['teens',
#    'break',
#    'dispensary',
#    'end',
#    'stealing',
#    'oregano',
#    'instead',
#    'weed'],
#   'negative'),
#  (['lens:', 'tenderly', 'photographing', 'end', 'her', 'father’s', 'life'],
#   'positive'),
#  (['five', 'thing', 'know', 'today'], 'neutral'),
#  (['character', 'study:', 'professor', 'roller', 'coaster'], 'neutral'),
#  (['first',
#    'f-35',
#    'fighter',
#    'jet',
#    'crash:',
#    'mystery',
#    'fault',
#    'force',
#    'pilot',
#    'eject',
#    'south',
#    'carolina'],
#   'negative'),
#  (['silicon', 'holler'], 'neutral'),
#  (["man's",
#    'bike',
#    'death',
#    "london's",
#    '10th',
#    'cycling',
#    'fatality',
#    '2018'],
#   'negative'),
#  (['colorado',
#    'river',
#    'boat',
#    'crash',
#    'death',
#    'toll',
#    'rise',
#    'searcher',
#    'recover',
#    'body',
#    'california',
#    'man'],
#   'negative'),
#  (['woman',
#    'crash',
#    'shot',
#    'allegedly',
#    'stealing',
#    "man's",
#    'truck',
#    'hotel',
#    'southwest',
#    'houston'],
#   'negative'),
#  (['tulare', "man's", 'body', 'pulled', 'colorado', 'river', 'boat', 'crash'],
#   'negative'),
#  (['south', 'sudan:', 'plane', 'crash', 'lake', 'yirol', "'killing", "19'"],
#   'negative'),
#  (['air',
#    'niugini',
#    'pilot',
#    'miss',
#    'runway',
#    '450',
#    'foot',
#    'crash-lands',
#    'boeing',
#    '737',
#    'lagoon'],
#   'negative'),
#  (['another',
#    'aging',
#    'air',
#    'force',
#    't-38',
#    'trainer',
#    'aircraft',
#    'crashed',
#    'texas',
#    'second',
#    'time',
#    'month'],
#   'neutral'),
#  (['f-35',
#    'fighter',
#    'jet',
#    'crash',
#    'south',
#    'carolina',
#    'day',
#    '$11.5bn',
#    'deal',
#    'announced'],
#   'neutral'),
#  (['donald',
#    'trump',
#    'used',
#    'noticeably',
#    'out-of-date',
#    'photo',
#    'commemorate',
#    '9/11.',
#    'ugh.'],
#   'negative'),
#  (['the', 'racism', 'inside', 'fire', 'departments'], 'negative'),
#  (['marcus',
#    'ericsson',
#    'survives',
#    '220mph',
#    'crash',
#    'practice',
#    'italian',
#    'grand',
#    'prix'],
#   'neutral'),
#  (['tesla',
#    'model',
#    'earns',
#    'five-star',
#    'crash',
#    'safety',
#    'rating',
#    'from',
#    'nhtsa'],
#   'neutral'),
#  (['when',
#    'facing',
#    'stock',
#    'market',
#    'crash,',
#    "here's",
#    'how',
#    'still',
#    'make',
#    'money'],
#   'negative'),
#  (['nasa',
#    'released',
#    'never-before-seen',
#    'photo',
#    'probe',
#    'went',
#    'missing',
#    'moon',
#    'year',
#    'ago'],
#   'negative'),
#  (['the', 'driver', 'slammed', 'tesla', 'firetruck', 'suing', '$300,000'],
#   'negative'),
#  (['people', 'dead', 'small', 'aircraft', 'crashed', 'lake', 'south', 'sudan'],
#   'negative'),
#  (['zambian', 'player', 'pay', 'respect', '1993', 'victim'], 'neutral'),
#  (['body', 'people', 'missing', 'california', 'boating', 'crash', 'recovered'],
#   'negative'),
#  (['boeing',
#    'jet',
#    'misses',
#    'runway',
#    'micronesia,',
#    'lands',
#    'lagoon',
#    'wall',
#    'street',
#    'journal'],
#   'negative'),
#  (['pedestrian', 'killed', 'lorry', 'crash', 'side', 'house'], 'negative'),
#  (['former',
#    'state',
#    'sen.',
#    'brian',
#    'joyce',
#    'found',
#    'dead',
#    'westport',
#    'home',
#    'fall',
#    'river',
#    'herald',
#    'news'],
#   'negative'),
#  (['drone', 'under', '$50', 'kid', 'love'], 'positive'),
#  (["'bbq",
#    "becky'",
#    'doppelgänger',
#    'interrupt',
#    'black',
#    'cosplayers',
#    'iconic',
#    'photo'],
#   'negative'),
#  (['death', 'toll', 'climb', 'new', 'mexico', 'bus', 'crash'], 'negative'),
#  (['crypto', 'market', 'crashing', 'hard,', "here's"], 'neutral'),
#  (['least', 'killed', 'head-on', 'bus', 'crash', 'new', 'mexico'], 'negative'),
#  (['the', 'decline', 'fall', 'new', 'york', 'city', 'ballet'], 'neutral'),
#  (['death', 'toll', 'rise', 'new', 'mexico', 'bus', 'crash'], 'negative'),
#  (['beto',
#    "o'rourke",
#    'say',
#    'passenger',
#    'back',
#    'claim',
#    'not',
#    'fleeing',
#    '1998',
#    'dui',
#    'crash',
#    'fox',
#    'news'],
#   'negative'),
#  (['your', '2018', 'emmys', 'crash', 'course'], 'negative'),
#  (['people', 'injured', 'missing', 'boat', 'collided', 'colorado', 'river'],
#   'negative'),
#  (['e-bike', 'crash', 'death', 'prompt', 'debate', 'safety', 'road'],
#   'negative'),
#  (['uber', 'roll', 'safety', 'features,', 'like', 'detect', 'crash', 'cnet'],
#   'positive'),
#  (['the', 'city', 'street,', 'decade', 'crash', 'picture'], 'negative'),
#  (['man', 'survived', 'florida', 'mass', 'shooting', 'dy', 'car', 'wreck'],
#   'neutral'),
#  (['woman', 'treated', 'antibiotic', 'develops', "'black", 'hairy', "tongue'"],
#   'neutral'),
#  (['terry',
#    'smith',
#    'best',
#    'money',
#    'manager',
#    'britain',
#    'ever',
#    'had?',
#    'patrick',
#    'collinson'],
#   'positive'),
#  (['will', 'smith', 'bungee', 'jump', 'helicopter', '50th', 'birthday'],
#   'neutral'),
#  (['how',
#    'one',
#    'comedy',
#    'club',
#    'successfully,',
#    'passive-aggressively',
#    'refused',
#    't.j.',
#    'miller'],
#   'positive'),
#  (['video',
#    'show',
#    'woman',
#    'trying',
#    'escape',
#    'foot',
#    'baby',
#    'car',
#    'crash',
#    'end',
#    '100mph',
#    'police',
#    'chase'],
#   'negative'),
#  (['father,',
#    'young',
#    'child',
#    'die',
#    'kayaking',
#    'accident',
#    'lake',
#    'superior;',
#    'mother',
#    'survives',
#    'fox',
#    'news'],
#   'negative'),
#  (['helicopter', 'crash', 'survivor', 'rescued', 'alaska;', 'missing'],
#   'neutral'),
#  (['airline', 'miracle', 'lagoon', 'landing', 'never', 'fatality'],
#   'positive'),
#  (['child', 'killed', 'crash', 'train,', 'bike'], 'negative'),
#  (['high-speed', 'chase', 'sparked', 'migrant', 'tragedy'], 'negative'),
#  (['hurricane', 'florence'], 'neutral'),
#  (['annemiek',
#    'van',
#    'vleuten',
#    'defends',
#    'world',
#    'time',
#    'trial',
#    'title',
#    'dutch',
#    'rider',
#    'dominate'],
#   'neutral'),
#  (['the', 'latest:', 'prison', 'term', 'crash', 'killed', 'colts', 'player'],
#   'negative'),
#  (['hard', 'brexiters’', 'new', 'plan', 'get', 'idiocy'], 'neutral'),
#  (['missing', 'boat', 'collide,', 'sink', 'colorado', 'river'], 'negative'),
#  (["fornite's", 'new', 'getaway', 'mode', 'fast', 'paced', 'comedy', 'errors'],
#   'neutral'),
#  (['the',
#    'saffir-simpson',
#    'hurricane',
#    'wind',
#    'scale',
#    "isn't",
#    'only',
#    'measure',
#    'florence’s',
#    'strength'],
#   'positive'),
#  (['security',
#    'researcher',
#    'share',
#    'web',
#    'code',
#    'snippet',
#    'cause',
#    'iphones',
#    'ipads',
#    'kernel',
#    'panic',
#    'reboot'],
#   'neutral'),
#  (['passengers,',
#    'crew',
#    'survive',
#    'air',
#    'niugini',
#    'plane',
#    'crash',
#    'sea',
#    'micronesia'],
#   'neutral'),
#  (['ford',
#    'recalls',
#    '1.6',
#    'million',
#    'f-150',
#    'pickups',
#    'seatbelt',
#    'fires'],
#   'neutral'),
#  (['tesla', 'share', 'fall', 'two', 'high-profile', 'executive', 'resign'],
#   'neutral'),
#  (['chinese',
#    'tesla',
#    'rival',
#    'nio',
#    'trim',
#    'ipo',
#    'target:',
#    'aim',
#    'raise',
#    '$1.5b'],
#   'neutral'),
#  (['eventbrite’s', 'ipo', 'encourage', 'tech', 'company', 'get', 'still'],
#   'positive'),
#  (['stormy', 'daniels', 'share', 'detail', 'alleged', 'affair'], 'positive'),
#  (['survivor', 'share', 'emotional', 'story'], 'positive'),
#  (['south',
#    'african',
#    'mainly',
#    'white',
#    'trade',
#    'union',
#    'strike',
#    "'racial",
#    "exclusion'"],
#   'negative'),
#  (['ariana', 'grande', 'share', 'heartbreaking', 'tribute', 'mac', 'miller'],
#   'negative'),
#  (['snapchat',
#    'share',
#    'hit',
#    'all-time',
#    'low',
#    'search',
#    'acquisition',
#    'vurb’s',
#    'ceo',
#    'bail'],
#   'neutral'),
#  (['tesla', 'share', 'fall', '10%', 'sec', 'fraud', 'charge', 'elon', 'musk'],
#   'negative'),
#  (['your',
#    'friday',
#    'news',
#    'briefing:',
#    'christine',
#    'blasey',
#    'ford,',
#    'boston',
#    'red',
#    'sox,',
#    '‘maniac’'],
#   'neutral'),
#  (['recruiting',
#    'win,',
#    'gm’s',
#    'cruise',
#    'employee',
#    'offered',
#    'equity',
#    'cruise'],
#   'positive'),
#  (['eventbrite', 'set', 'ipo', 'range', '$19', '$21,', 'valuing', '$1.8b'],
#   'positive'),
#  (['deep-linking',
#    'startup',
#    'branch',
#    'raising',
#    '$100m',
#    'unicorn',
#    'valuation'],
#   'neutral'),
#  (['how', 'conquer', 'your', 'fears,', 'with', 'author', 'dean', 'sluyter'],
#   'negative'),
#  (['asian',
#    'share',
#    'weather',
#    'fed',
#    'rate',
#    'hike,',
#    'u.s.',
#    'bond',
#    'yield',
#    'fall'],
#   'positive'),
#  (['fund',
#    'raise',
#    '$200',
#    'million',
#    'lend',
#    'cash',
#    'startup',
#    'employee',
#    'whose',
#    'liquidity',
#    'locked',
#    'equity'],
#   'neutral'),
#  (['fears', "musk's", 'future', 'sink', 'tesla', 'share'], 'neutral'),
#  (['terry',
#    'crews',
#    'share',
#    'apology',
#    'letter',
#    'agent',
#    'allegedly',
#    'assaulted'],
#   'negative'),
#  (['fears', "musk's", 'future', 'sink', 'tesla', 'share'], 'neutral'),
#  (['cynthia',
#    'nixon',
#    'loses',
#    'primary',
#    'share',
#    'powerful',
#    'message',
#    'young',
#    'people',
#    'twitter'],
#   'positive'),
#  (['peter',
#    'dinklage',
#    'share',
#    'tyrion',
#    'thinking',
#    'jon',
#    'dany',
#    'hooked'],
#   'positive'),
#  (['maisie',
#    'williams',
#    'share',
#    'moment',
#    'knew',
#    'big',
#    "'game",
#    "thrones'",
#    'actually'],
#   'positive'),
#  (['native', 'support', 'windows', 'file', 'sharing', 'coming', 'chrome'],
#   'positive'),
#  (['elon',
#    'musk’s',
#    'fans',
#    'just',
#    'took',
#    'big',
#    'hit',
#    'tesla',
#    'shares',
#    'tank'],
#   'positive'),
#  (['tesla',
#    'ceo',
#    'elon',
#    'musk',
#    'call',
#    'sec',
#    'security',
#    'fraud',
#    'charge',
#    '“unjustified',
#    'action”'],
#   'negative'),
#  (['fitbit', 'falls,', 'garmin', 'shed', 'gain', 'new', 'apple', 'watch'],
#   'positive'),
#  (['fedex',
#    'cup',
#    'play-offs:',
#    'justin',
#    'rose',
#    'advantage',
#    'tiger',
#    'woods',
#    'share',
#    'tour',
#    'championship',
#    'lead'],
#   'positive'),
#  (['book',
#    'baby',
#    'are',
#    'due',
#    'same',
#    'day!',
#    'follow',
#    'along',
#    'journey.',
#    'episode',
#    '11:',
#    'done',
#    'better',
#    'than',
#    'perfect.'],
#   'positive'),
#  (['how', 'optimize', 'your', 'mind,', 'optimizing', 'your', 'body'],
#   'positive'),
#  (['asian', 'share', 'rise', 'investor', 'reassess', 'trade', 'war', 'impact'],
#   'negative'),
#  (["sky's", 'share', 'jump', 'comcast', 'win', 'auction', 'knockout', 'blow'],
#   'positive'),
#  (["sky's", 'share', 'jump', 'comcast', 'win', 'auction', 'big', 'bet'],
#   'positive'),
#  (['asian', 'share', 'slugged', 'new', 'u.s.', 'tariff', 'threat'],
#   'negative'),
#  ...]

# %% [markdown]
# ## Build Classifier

# %%
def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)    
    word_features = wordlist.keys()
    return word_features

# %%
def get_words_in_articles(articles):
    all_words = []
    for (words, sentiment) in articles:
        all_words.extend(words)
    return all_words

# %%
word_features = get_word_features(get_words_in_articles(article_word_list))

# %%
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
training_set = nltk.classify.apply_features(extract_features, article_word_list)

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
#Print the most informative features using this function
classifier.show_most_informative_features(10)
# Out:
# Most Informative Features
#           contains(loss) = True           negati : neutra =     13.3 : 1.0
#          contains(great) = True           positi : neutra =     13.2 : 1.0
#           contains(made) = True           positi : neutra =     12.2 : 1.0
#           contains(risk) = True           negati : neutra =     11.3 : 1.0
#         contains(shares) = True           positi : neutra =     11.3 : 1.0
#            contains(win) = True           positi : neutra =     11.3 : 1.0
#        contains(warning) = True           negati : neutra =      8.4 : 1.0
#         contains(profit) = True           positi : neutra =      8.3 : 1.0
#            contains(top) = True           positi : neutra =      8.3 : 1.0
#          contains(death) = True           negati : neutra =      8.0 : 1.0

# %% [markdown]
# ## Classify

# %%
def classify(words):
    return classifier.classify(extract_features(words.split()))

# %%
def classify_sia(words):
    ss = sid.polarity_scores(words)
    polarity = ss['compound']
    return 'positive' if polarity>0 else 'negative' if polarity<0 else 'neutral'

# %% [markdown]
# ## Testing Accuracy

# %%
news_results = newsapi.get_everything(q='sustainability', page_size=100)
test_articles = pd.DataFrame(news_results['articles'])

# %%
test_articles['sentiment_classifier'] = test_articles['title'].apply(classify)

# %%
test_articles['sentiment_sia'] = test_articles['title'].apply(classify_sia)

# %%
test_articles.head()
# Out:
#               author                                            content  \
# 0       JAMES BARRON  She said her awareness of environmental concer...
# 1    Chiara Cecchini  From Singapore to the USA and all around Europ...
# 2       Brian Heater  It’s been a rough few months for MoviePass. Bu...
# 3     Seamus Bellamy  Apple has always talked a good game where recy...
# 4  Megan Rose Dickey  Lyft is on a bit of a Tesla poaching spree whi...
#
#                                          description           publishedAt  \
# 0  Sarah Kauss, the founder of S’well, and Mark C...  2018-09-23T14:00:04Z
# 1  From green tea to kombucha, the humble tea has...  2018-09-06T13:00:00Z
# 2  It’s been a rough few months for MoviePass. Bu...  2018-09-17T14:33:20Z
# 3  Apple has always talked a good game where recy...  2018-09-14T22:42:52Z
# 4  Lyft is on a bit of a Tesla poaching spree whi...  2018-09-14T15:00:17Z
#
#                                               source  \
# 0  {'id': 'the-new-york-times', 'name': 'The New ...
# 1               {'id': None, 'name': 'Makezine.com'}
# 2         {'id': 'techcrunch', 'name': 'TechCrunch'}
# 3             {'id': None, 'name': 'Boingboing.net'}
# 4         {'id': 'techcrunch', 'name': 'TechCrunch'}
#
#                                                title  \
# 0  Grace Notes: From a 1993 Vow to 320,000 Reusab...
# 1  Edible Innovation: All for Bamboo, All for Sus...
# 2  MoviePass competitor Sinemia launches unlimite...
# 3  Apple's claims about recycling and sustainabil...
# 4           Lyft hires yet another ex-Tesla employee
#
#                                                  url  \
# 0  https://www.nytimes.com/2018/09/23/nyregion/sw...
# 1  https://makezine.com/2018/09/06/edible-innovat...
# 2  http://techcrunch.com/2018/09/17/moviepass-com...
# 3  https://boingboing.net/2018/09/14/apples-claim...
# 4  http://techcrunch.com/2018/09/14/lyft-hires-ye...
#
#                                           urlToImage sentiment_classifier  \
# 0  https://static01.nyt.com/images/2018/09/24/nyr...              neutral
# 1  https://i2.wp.com/makezine.com/wp-content/uplo...              neutral
# 2  https://techcrunch.com/wp-content/uploads/2018...              neutral
# 3  https://media.boingboing.net/wp-content/upload...             negative
# 4  https://techcrunch.com/wp-content/uploads/2018...              neutral
#
#   sentiment_sia
# 0      positive
# 1      positive
# 2       neutral
# 3      negative
# 4       neutral

# %%
test_articles_copy = test_articles.copy()
test_articles_copy['accuracy'] = test_articles_copy['sentiment_classifier']==test_articles_copy['sentiment_sia']

# %%
accurate = test_articles_copy[test_articles_copy['accuracy']==True]

# %%
accurate.shape
# Out:
# (73, 11)

# %%
test_articles_copy.shape
# Out:
# (100, 11)

# %%
json_object = json.loads(test_articles.to_json(orient='records'))
final_json = {'articles': json_object, 
             'totalResults': news_results['totalResults']}
final_json
# Out:
# {'articles': [{'author': 'JAMES BARRON',
#    'content': 'She said her awareness of environmental concerns began before the high-school water fountain and the college pledge. We were the first family on my street to have recycling bins, said Ms. Kauss, who grew up in South Florida. I have a fond memory of my dad fil… [+2460 chars]',
#    'description': 'Sarah Kauss, the founder of S’well, and Mark Chambers, the director of the Mayor’s Office of Sustainability, at S’well in Manhattan last week. They are working to slow the stream of discarded plastic bottles that clog waterways, threatening marine life, and t…',
#    'publishedAt': '2018-09-23T14:00:04Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'the-new-york-times', 'name': 'The New York Times'},
#    'title': 'Grace Notes: From a 1993 Vow to 320,000 Reusable Water Bottles for Every New York High Schooler',
#    'url': 'https://www.nytimes.com/2018/09/23/nyregion/swell-water-bottles-nyc-high-schools.html',
#    'urlToImage': 'https://static01.nyt.com/images/2018/09/24/nyregion/24grace2/24grace2-facebookJumbo.jpg'},
#   {'author': 'Chiara Cecchini',
#    'content': 'From Singapore to the USA and all around Europe, Edible Innovations profiles food makers that engage in improving the global food system at every stage, from production to distribution to eating and shopping. Join us as we explore the main trends in the indus… [+3677 chars]',
#    'description': 'From green tea to kombucha, the humble tea has been around for centuries. Read more on MAKE The post Edible Innovation: All for Bamboo, All for Sustainability! appeared first on Make: DIY Projects and Ideas for Makers.',
#    'publishedAt': '2018-09-06T13:00:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Makezine.com'},
#    'title': 'Edible Innovation: All for Bamboo, All for Sustainability!',
#    'url': 'https://makezine.com/2018/09/06/edible-innovation-all-for-bamboo-all-for-sustainability/',
#    'urlToImage': 'https://i2.wp.com/makezine.com/wp-content/uploads/2018/09/Screen-Shot-2018-09-03-at-6.45.26-PM.png?fit=1126%2C902&ssl=1'},
#   {'author': 'Brian Heater',
#    'content': 'It’s been a rough few months for MoviePass. But every time the movie subscription service has faltered, one company has been there to pick up the pieces. Sinemia has done a solid job benefiting from MoviePass’s woes, even seeming to taunt its chief competitor… [+1181 chars]',
#    'description': 'It’s been a rough few months for MoviePass. But every time the movie subscription service has faltered, one company has been there to pick up the pieces. Sinemia has done a solid job benefiting from MoviePass’s woes, even seeming to taunt its chief competitor…',
#    'publishedAt': '2018-09-17T14:33:20Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'title': 'MoviePass competitor Sinemia launches unlimited plan',
#    'url': 'http://techcrunch.com/2018/09/17/moviepass-competitor-sinemia-launches-unlimited-plan/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/05/gettyimages-92147914-e1527111507797.jpg?w=600'},
#   {'author': 'Seamus Bellamy',
#    'content': "Apple has always talked a good game where recycling and environmentalism are concerned. They're quick to point out that they recycle what they can and are always on the hunt for new, sustainable manufacturing practices to adopt. They've got robots named Liam … [+4814 chars]",
#    'description': "Apple has always talked a good game where recycling and environmentalism are concerned. They're quick to point out that they recycle what they can and are always on the hunt for new, sustainable manufacturing practices to adopt. They've got robots named Liam …",
#    'publishedAt': '2018-09-14T22:42:52Z',
#    'sentiment_classifier': 'negative',
#    'sentiment_sia': 'negative',
#    'source': {'id': None, 'name': 'Boingboing.net'},
#    'title': "Apple's claims about recycling and sustainability are kinda entirely nonsense",
#    'url': 'https://boingboing.net/2018/09/14/apples-claims-about-recyclin.html',
#    'urlToImage': 'https://media.boingboing.net/wp-content/uploads/2018/09/technology-telephone-mobile-smart-1388947.jpg'},
#   {'author': 'Megan Rose Dickey',
#    'content': 'Lyft is on a bit of a Tesla poaching spree while Tesla employees are exiting in droves. The latest ex-Tesla employee to join Lyft is Cal Lankton, who most recently led the development of Tesla’s electric vehicle charging network up until May. At Lyft, Lankton… [+1627 chars]',
#    'description': 'Lyft is on a bit of a Tesla poaching spree while Tesla employees are exiting in droves. The latest ex-Tesla employee to join Lyft is Cal Lankton, who most recently led the development of Tesla’s electric vehicle charging network up until May. At Lyft, Lankton…',
#    'publishedAt': '2018-09-14T15:00:17Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'title': 'Lyft hires yet another ex-Tesla employee',
#    'url': 'http://techcrunch.com/2018/09/14/lyft-hires-yet-another-ex-tesla-employee/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/09/Lyft_Cal_Lankton-e1536878337660.jpg?w=552'},
#   {'author': 'Allison Aubrey',
#    'content': "A farmer in India piles millet in a field. Grains such as millet and sorghum pack a powerful nutritional punch, but they are overlooked for calorie-laden commodity crops such as wheat or maize. Sam Panthaky/AFP/Getty Images There's a lot of talk about how to … [+6633 chars]",
#    'description': 'As United Nations leaders gather in New York, top food and nutrition experts are convening for a forum to talk about how people around the globe can have both a nourished diet and a healthy planet.',
#    'publishedAt': '2018-09-23T11:00:28Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Npr.org'},
#    'title': 'Do Healthy Diets Protect The Planet? As The U.N. Meets, A Focus On Sustainability',
#    'url': 'https://www.npr.org/sections/thesalt/2018/09/23/650485867/do-healthy-diets-protect-the-planet-as-the-u-n-meets-a-focus-on-sustainability',
#    'urlToImage': 'https://media.npr.org/assets/img/2018/09/21/millet_wide-09c639037398abe0dd6c42579e211bf2dcc9b0c3.jpg?s=1400'},
#   {'author': 'Eillie Anzilotti',
#    'content': 'Starbucks owns and operates over 28,000 stores worldwide. By 2025, the coffee behemoth is aiming for 10,000 of them–some old, some yet to open–to meet a new set of sustainability requirements. The Greener Stores Framework, as Starbucks is calling it, lays out… [+3179 chars]',
#    'description': 'In a new six-part framework, the coffee retailer spells out a new, open-source set of sustainability standards for its retail stores. Starbucks owns and operates over 28,000 stores worldwide. By 2025, the coffee behemoth is aiming for 10,000 of them–some old,…',
#    'publishedAt': '2018-09-13T12:45:19Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Fastcompany.com'},
#    'title': 'Starbucks is making its stores more sustainable–and wants to help others do the same',
#    'url': 'https://www.fastcompany.com/90236213/starbucks-launches-a-new-store-sustainability-framework?partner=feedburner&utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+fastcompany%2Fheadlines+%28Fast+Company%29',
#    'urlToImage': 'https://images.fastcompany.net/image/upload/w_1280,f_auto,q_auto,fl_lossy/wp-cms/uploads/2018/09/i-1-90236213-starbucks-wants-its-stores-to-be-even-more-green.jpg'},
#   {'author': 'Yossi Sheffi',
#    'content': 'W arren Buffett said, “It takes 20 years to build a reputation and five minutes to ruin it.” It has been more than two decades now since a 1996 issue of Life magazine depicted a Pakistani boy sewing a Nike soccer ball, reportedly for six cents per hour. After… [+5258 chars]',
#    'description': 'Sustainability can bring benefits to everybody – including company execs with their eyes on the bottom line Warren Buffett said, “It takes 20 years to build a reputation and five minutes to ruin it.” It has been more than two decades now since a 1996 issue of…',
#    'publishedAt': '2018-09-07T06:30:32Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'title': 'Profits v planet: can big business and the environment get along? | Yossi Sheffi',
#    'url': 'https://www.theguardian.com/environment/2018/sep/07/profits-v-planet-can-big-business-and-the-environment-get-along',
#    'urlToImage': 'https://i.guim.co.uk/img/media/3b19aec068acbc6f228279f7e8b63baf1772f1b1/0_95_3000_1800/master/3000.jpg?width=1200&height=630&quality=85&auto=format&usm=12&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvNTM4OGZjODViNTQ0N2E4M2NmMWNlMTg5YTVhMjE1NzMvdGctb3BpbmlvbnMucG5n&s=87cbdad203a74e0f73f0ebc81eb5ac01'},
#   {'author': 'Arielle Pardes',
#    'content': "In a basement in San Francisco, Lavion Gibson circles tiny imperfections on the soles of shoes with a red marker. The blemishes he's identifying are barely perceptible to the naked eye—a small pock, or an inconsistency in the finish. But to Gibson, the senior… [+11430 chars]",
#    'description': 'The company made its name on a line of footwear made of yarn spun from plastic. Today, it adds a new sneaker with a customizable fit to its offerings.',
#    'publishedAt': '2018-09-13T13:00:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'wired', 'name': 'Wired'},
#    'title': "A Behind the Scenes Look at Rothy's New Sneaker",
#    'url': 'https://www.wired.com/story/rothys-sneaker/',
#    'urlToImage': 'https://media.wired.com/photos/5b99aba108bfd37b327cfadb/191:100/pass/SneakerGroupShot1.jpg'},
#   {'author': 'Jon Russell',
#    'content': 'Despite a bear market that has seen the price of Ethereum drop by over 80 percent since the start of the year, most projects that raised money via an ICO remain unaffected, according to the findings of a new report. Bitmex, best known for a crypto trading ser… [+3288 chars]',
#    'description': 'Despite a bear market that has seen the price of Ethereum drop by over 80 percent since the start of the year, most projects that raised money via an ICO remain unaffected, according to the findings of a new report. Bitmex, best known for a crypto trading ser…',
#    'publishedAt': '2018-10-01T11:03:59Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'negative',
#    'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'title': 'Report: Most ICO project financing unaffected by crypto market crash',
#    'url': 'http://techcrunch.com/2018/10/01/ico-project-financing-crypto-crash/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2018/10/Photo-01-10-2018-17-54-22.jpg?w=750'},
#   {'author': 'https://www.facebook.com/bbcnews',
#    'content': 'Image caption Local, high-quality food is already popular - but will the Swiss pay more for ethical farming? Switzerland is going to the polls on Sunday, in not one but two votes which campaigners say will promote ethical and sustainable food. The votes follo… [+4097 chars]',
#    'description': 'In a country where food is already expensive, the people are set to vote on tighter quality control.',
#    'publishedAt': '2018-09-22T23:46:14Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'bbc-news', 'name': 'BBC News'},
#    'title': "Switzerland considers tighter rules on sustainable 'fair food'",
#    'url': 'https://www.bbc.co.uk/news/world-europe-45600282',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/4D96/production/_103526891_3farmersmarket.png'},
#   {'author': 'LISA W. FODERARO',
#    'content': '“Everything that I do in this development, he is a part of, and I mean that literally,” Ms. Johnson said. Despite her traction with progressive groups, Ms. Biaggi has struggled to amass a significant fraction of Mr. Klein’s war chest. According to state elect… [+1994 chars]',
#    'description': 'State Senator Jeffrey Klein, the former leader of the now-defunct Independent Democratic Conference, has spent $2.4 million in his primary race against Alessandra Biaggi.',
#    'publishedAt': '2018-09-12T00:11:39Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'the-new-york-times', 'name': 'The New York Times'},
#    'title': 'He Led a Group of Disloyal New York Democrats. Will It Cost Him His Seat?',
#    'url': 'https://www.nytimes.com/2018/09/11/nyregion/jeffrey-klein-alessandra-biaggi.html',
#    'urlToImage': 'https://static01.nyt.com/images/2018/09/12/nyregion/12KLEINsub/12KLEINsub-facebookJumbo.jpg'},
#   {'author': 'Adele Peters',
#    'content': 'Looking at a city’s Google Maps data, in combination with other data, a new tool from Google can estimate the carbon footprint of all of its buildings–and the carbon footprint of all the car trips, bus and subway rides, and other transportation used by the pe… [+2522 chars]',
#    'description': 'The Environmental Insights Explorer calculates emissions from buildings, car trips, and public transport to illustrate how a city’s sustainability efforts are faring. Looking at a city’s Google Maps data, in combination with other data, a new tool from Google…',
#    'publishedAt': '2018-09-10T11:00:10Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Fastcompany.com'},
#    'title': 'A new use for Google Maps: calculating a city’s carbon footprint',
#    'url': 'https://www.fastcompany.com/90233731/a-new-use-for-google-maps-calculating-a-citys-carbon-footprint?partner=feedburner&utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+fastcompany%2Fheadlines+%28Fast+Company%29',
#    'urlToImage': 'https://images.fastcompany.net/image/upload/w_1280,f_auto,q_auto,fl_lossy/wp-cms/uploads/2018/09/p-1-90233731-google-tool-environmental-insights-explorer.jpg'},
#   {'author': 'Barrett Wissman',
#    'content': 'September 20, 2018 5 min read Opinions expressed by Entrepreneur contributors are their own. It finally happened. An entire company swore off meat. Citing environmental concerns, WeWork banned meat in a bold attempt to save the planet. In a nod to Elon Musk, … [+4637 chars]',
#    'description': 'Consumers are ever more impatient for brands to embrace the greater good.',
#    'publishedAt': '2018-09-20T11:30:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Entrepreneur.com'},
#    'title': "You Don't Have to Be Elon Musk to Make a Difference",
#    'url': 'https://www.entrepreneur.com/article/319935',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/20180919140919-GettyImages-974773044.jpeg'},
#   {'author': 'Emma Jacobs',
#    'content': 'I first arrived at university to find my whole flat was vegetarian or vegan. It was a surprise to see the fridge was full of Alpro desserts and homemade hummus. But perhaps I shouldn’t have been shocked: we students are six times more likely than our parents … [+4481 chars]',
#    'description': 'From homemade Vietnamese pho to takeaway tofu scampi, there are plenty of cheap and healthy animal-free options I first arrived at university to find my whole flat was vegetarian or vegan. It was a surprise to see the fridge was full of Alpro desserts and hom…',
#    'publishedAt': '2018-09-18T14:26:46Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'title': 'No fresh meat: how to eat vegan on a student budget',
#    'url': 'https://www.theguardian.com/education/2018/sep/18/no-fresh-meat-how-to-eat-vegan-on-a-student-budget',
#    'urlToImage': 'https://i.guim.co.uk/img/media/0e59404983193d30a02c6ff0e8e2f058701e005c/0_176_5467_3281/master/5467.jpg?width=1200&height=630&quality=85&auto=format&usm=12&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvZDM1ODZhNWVmNTc4MTc1NmQyMWEzYjYzNWU1MTcxNDEvdGctZGVmYXVsdC5wbmc&s=e3067a5deb2bdcd8b4248ad2cdff4bb2'},
#   {'author': 'Eillie Anzilotti',
#    'content': 'It’s been a big year for Lyft. In July, the ride-sharing company inked a $250 million acquisition deal with Motivate, the largest bike-share operator in the United States. Its market share, while still lagging behind that of its embattled competitor Uber, gre… [+1574 chars]',
#    'description': 'Every aspect of the ride-sharing company’s operations will be neutralized through carbon offsetting. It’s been a big year for Lyft. In July, the ride-sharing company inked a $250 million acquisition deal with Motivate, the largest bike-share operator in the U…',
#    'publishedAt': '2018-09-11T09:00:36Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Fastcompany.com'},
#    'title': 'Lyft: “We are now a fully carbon-neutral company”',
#    'url': 'https://www.fastcompany.com/90234646/lyft-we-are-now-a-fully-carbon-neutral-company?partner=feedburner&utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+fastcompany%2Fheadlines+%28Fast+Company%29',
#    'urlToImage': 'https://images.fastcompany.net/image/upload/w_1280,f_auto,q_auto,fl_lossy/wp-cms/uploads/2018/09/p-1-lyft-we-are-now-a-fully-carbon-neutral-company.jpg'},
#   {'author': 'feedback@businessinsider.com (Taylor Tobin), Taylor Tobin',
#    'content': 'From ramen to pad Thai, noodle dishes tend to rank among the most popular picks for delivered meals. But unfortunately, a lot can go wrong when these items get set into literal motion. Darren Sayphraraj, chef and owner of We Have Noodles in Silver Lake, Los A… [+944 chars]',
#    'description': 'Flickr When it comes to delivery eats, the classics are, well... classic for a reason. Pizza and Chinese food claim the top spots in the delivery food pantheon because they’re delicious, they’re satisfying, and they travel exceptionally well. But if you’re cr…',
#    'publishedAt': '2018-09-13T15:18:54Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Thisisinsider.com'},
#    'title': '6 of the best foods to get delivered',
#    'url': 'https://www.thisisinsider.com/best-foods-for-delivery-2018-9',
#    'urlToImage': 'https://amp.businessinsider.com/images/5b9a81032badb95dd10b7b1a-960-480.jpg'},
#   {'author': 'Matthew DeBord',
#    'content': "Taylor cofounder Bob Taylor. Taylor It's like something out of a movie: a seasoned entrepreneur and environmentally conscious leader decides to buy and transform a sawmill in Cameroon. But if anybody was going to undertake such a daunting project, it would Bo… [+5610 chars]",
#    'description': "San Diego-based Taylor Guitars has made a substantial investment in a sawmill in Cameroon to provide the innovative company with a sustainable supply of an essential wood, ebony. Under co-founder and CEO Bob Taylor's leadership, the company upgraded the sawmi…",
#    'publishedAt': '2018-09-18T18:55:06Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'title': 'Taylor Guitars took a big risk by investing in an African sawmill — but according the CEO, it was a great move by the company',
#    'url': 'https://www.businessinsider.com/taylor-guitars-ebony-project-2018-8',
#    'urlToImage': 'https://amp.businessinsider.com/images/5b9bfdf2959f34ef318b5144-1136-568.jpg'},
#   {'author': 'Dezeen staff',
#    'content': "Dezeen promotion: Danish tap manufacturer Vola has released a series of short films, which explore everything from its relationship with water to its approach to sustainability, to mark the brand's 50th birthday. The six films focus on Vola 's core brand valu… [+1469 chars]",
#    'description': "Dezeen promotion: Danish tap manufacturer Vola has released a series of short films, which explore everything from its relationship with water to its approach to sustainability, to mark the brand's 50th birthday. Read more",
#    'publishedAt': '2018-09-20T14:20:13Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Dezeen.com'},
#    'title': 'Vola celebrates 50th birthday with series of short films',
#    'url': 'http://www.dezeen.com/2018/09/20/vola-danish-tap-50th-birthday-short-films/',
#    'urlToImage': 'https://static.dezeen.com/uploads/2018/09/vola-design-products-taps-promotions_dezeen_hero-1.jpg'},
#   {'author': 'Sandra Laville',
#    'content': 'Global soft drink companies have made their biggest commitment yet to eliminating the use of throwaway plastic bottles, in an action plan presented to parliament. In a report sponsored by the likes of Danone, Suntory and Nestlé, the companies give unequivocal… [+2520 chars]',
#    'description': 'Industry makes biggest commitment yet to ending its use of throwaway plastic bottles Global soft drink companies have made their biggest commitment yet to eliminating the use of throwaway plastic bottles, in an action plan presented to parliament. In a report…',
#    'publishedAt': '2018-09-06T17:30:48Z',
#    'sentiment_classifier': 'negative',
#    'sentiment_sia': 'negative',
#    'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'title': 'Global soft drink firms back plan to eliminate packaging waste',
#    'url': 'https://www.theguardian.com/environment/2018/sep/06/global-soft-drink-firms-back-plan-to-eliminate-packaging-waste',
#    'urlToImage': 'https://i.guim.co.uk/img/media/e479d16982f6fd675158cfce5b0fe7ff68aa307f/0_356_5400_3242/master/5400.jpg?width=1200&height=630&quality=85&auto=format&usm=12&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvZDM1ODZhNWVmNTc4MTc1NmQyMWEzYjYzNWU1MTcxNDEvdGctZGVmYXVsdC5wbmc&s=1c18d39142af77c37a48642497f33503'},
#   {'author': 'Paul Rees',
#    'content': 'T he Welsh Rugby Union chief executive, Martyn Phillips, has backed calls by Agust ín Pichot for action to be taken to secure the future of international rugby, saying the current formula does not have any long-term sustainability. The WRU has announced a bum… [+7020 chars]',
#    'description': 'A World Rugby conference in Sydney next week will discuss how to reinvent the international game, something that can only be achieved by working with clubs too The Welsh Rugby Union chief executive, Martyn Phillips, has backed calls by Agust ín Pichot for act…',
#    'publishedAt': '2018-09-20T12:08:00Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'title': 'World must march in union to secure future of international rugby | The Breakdown',
#    'url': 'https://www.theguardian.com/sport/2018/sep/20/world-union-future-international-rugby-the-breakdown',
#    'urlToImage': 'https://i.guim.co.uk/img/media/f1743586c3bb8c9909d6af3c682ac7184d363203/0_227_3600_2159/master/3600.jpg?width=1200&height=630&quality=85&auto=format&usm=12&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvZDM1ODZhNWVmNTc4MTc1NmQyMWEzYjYzNWU1MTcxNDEvdGctZGVmYXVsdC5wbmc&s=91084f37bcc91057f1940c5aa96d0ee5'},
#   {'author': 'Troy Turner',
#    'content': 'A recent winner of the 2018 James Dyson Award, the Layer shoe explores modularity and sustainability without sacrificing style. Designed using biodegradable and recycled materials, users can customize their shoe from the start and continue to repair and reima… [+3526 chars]',
#    'description': 'Footwear that Never Ends and Only Changes A recent winner of the 2018 James Dyson Award, the Layer shoe explores modularity and sustainability without sacrificing style. Designed using biodegradable and recycled materials, users...',
#    'publishedAt': '2018-09-19T05:07:25Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Yankodesign.com'},
#    'title': 'Footwear that Never Ends and Only Changes',
#    'url': 'http://www.yankodesign.com/2018/09/18/footwear-that-never-ends-and-only-changes/',
#    'urlToImage': None},
#   {'author': 'Rina Raphael',
#    'content': 'We’ve all heard about the benefits of plant-based meat alternatives: reduced cholesterol, less impact on the land, animal-friendly, etc. But in terms of its reportedly environmentally friendly practices, how exactly does it measure up to traditional meat? Bey… [+3550 chars]',
#    'description': 'According to a new study, a 41-square-foot plot of land can produce just one beef burger for every 15 Beyond Burgers. We’ve all heard about the benefits of plant-based meat alternatives: reduced cholesterol, less impact on the land, animal-friendly, etc. But …',
#    'publishedAt': '2018-09-26T07:09:04Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Fastcompany.com'},
#    'title': 'Meatless burgers vs. beef: How Beyond Meat’s environmental impact stacks up',
#    'url': 'https://www.fastcompany.com/90241836/meatless-burgers-vs-beef-how-beyond-meats-environmental-impact-stacks-up?partner=feedburner&utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+fastcompany%2Fheadlines+%28Fast+Company%29',
#    'urlToImage': 'https://images.fastcompany.net/image/upload/w_1280,f_auto,q_auto,fl_lossy/wp-cms/uploads/2018/09/p-2-environmental-study-how-beyond-meatand8217s-plant-based-burgers-compare-to-beef.jpg'},
#   {'author': 'aismael@businessinsider.com (Amir Ismael), Amir Ismael',
#    'content': "The Insider Picks team writes about stuff we think you'll like. Business Insider has affiliate partnerships, so we get a share of the revenue from your purchase. For more than 85 years, Danner has been one most dependable brands for outdoor boots made to last… [+4023 chars]",
#    'description': "The Insider Picks team writes about stuff we think you'll like. Business Insider has affiliate partnerships, so we get a share of the revenue from your purchase. United By Blue Outdoor startup and relative newcomer United By Blue teamed up with legendary Dann…",
#    'publishedAt': '2018-09-17T19:43:00Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'title': "Danner Boots partnered with a small outdoors startup to give its classic pair of hiking boots a sustainable facelift — here's why they're worth the cost",
#    'url': 'https://www.businessinsider.com/united-by-blue-danner-boots-bison-collection-review-2018-9',
#    'urlToImage': 'https://amp.businessinsider.com/images/5b9fb595e361c018008b5c78-2732-1366.jpg'},
#   {'author': 'Will Martin',
#    'content': 'Global Commission on the Economy and Climate report looks at upsides of action on climate change. Mike Hutchings/Reuters Bold action on climate change could add more than $2 trillion a year to the global economy over the next decade, according to a major new … [+2512 chars]',
#    'description': 'A new report argues that quicker action on climate change could add more than $2 trillion a year to the global economy over the next decade. The report, from the Global Commission on the Economy and Climate (GCEC), argues that increasing investments in sustai…',
#    'publishedAt': '2018-09-05T08:56:32Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'title': 'The world economy could grow $26 trillion in a decade if governments and businesses focus on climate change',
#    'url': 'https://www.businessinsider.com/global-commission-on-the-economy-and-climate-report-2018-9',
#    'urlToImage': 'https://amp.businessinsider.com/images/592493b534911bd5008b5e3d-2732-1366.jpg'},
#   {'author': 'Rosie Mattio',
#    'content': 'September 24, 2018 3 min read Opinions expressed by Green Entrepreneur contributors are their own. The Golden State is the political and cultural epicenter of the legal cannabis movement. Though it wasnt the first state to legalize adult use (Colorado holds t… [+2493 chars]',
#    'description': 'These industry crazes have the West Coast buzzing. Could the rest of the legal world be far behind.',
#    'publishedAt': '2018-09-24T18:01:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Greenentrepreneur.com'},
#    'title': '3 Hottest Cannabis Trends In California',
#    'url': 'https://www.greenentrepreneur.com/article/320451',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/20151201223652-hollywood-blvd-street-sunset-california.jpeg'},
#   {'author': 'Chris Taylor',
#    'content': "It's launch day for the iPhone XS and XS Max. And if it seems a little muted compared to iPhone launch days past, that may be because Apple is making it increasingly easy to hang on to your three-year-old phone instead — even if they no longer sell that phone… [+4384 chars]",
#    'description': "It's launch day for the iPhone XS and XS Max. And if it seems a little muted compared to iPhone launch days past, that may be because Apple is making it increasingly easy to hang on to your three-year-old phone instead — even if they no longer sell that phone…",
#    'publishedAt': '2018-09-21T20:51:46Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'mashable', 'name': 'Mashable'},
#    'title': 'Thanks, Apple, for making it easy to cling to my iPhone 6S',
#    'url': 'https://mashable.com/article/iphone-6s-ios-12-upgrade/',
#    'urlToImage': 'https://i.amz.mshcdn.com/5cAP838MYHYW6um-QWt0hf4L0Gc=/1200x630/2018%2F09%2F21%2F72%2Fd52ccf8f3e5c4161bd98c20521bd9ba5.4a2f2.jpg'},
#   {'author': 'Eillie Anzilotti',
#    'content': 'The day after Andrea Learned, a transportation and urban design consultant based in Seattle, flew down to San Francisco for the Global Climate Action Summit, a cyclist was struck and killed by a car while trying to navigate around an illegally parked truck on… [+6755 chars]',
#    'description': 'By 2050, if even just 7% more trips were made by bike and foot, we could avoid around 5 gigatons of carbon emissions. It’s simple, but effective. The day after Andrea Learned, a transportation and urban design consultant based in Seattle, flew down to San Fra…',
#    'publishedAt': '2018-09-27T12:30:47Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'negative',
#    'source': {'id': None, 'name': 'Fastcompany.com'},
#    'title': 'As we discuss big solutions to climate change, don’t forget people-friendly streets',
#    'url': 'https://www.fastcompany.com/90241298/as-we-discuss-big-solutions-to-climate-change-dont-forget-people-friendly-streets?partner=feedburner&utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+fastcompany%2Fheadlines+%28Fast+Company%29',
#    'urlToImage': 'https://images.fastcompany.net/image/upload/w_1280,f_auto,q_auto,fl_lossy/wp-cms/uploads/2018/09/p-1-90241298-amid-all-the-climate-action-this-month-donand8217t-forget-about-people-friendly-streets.jpg'},
#   {'author': 'Ben Fisher',
#    'content': 'It is the afternoon of 29 August, the day after a record-low crowd of 4,666 witnessed Hull crash to a 4-0 home defeat to Derby in the Carabao Cup. That number, Hull’s lowest attendance at the KCom Stadium – their home since Boxing Day 2002 – paints part of th… [+7988 chars]',
#    'description': 'The club’s co-owner is keen to sell up amid a toxic time at the KCom Stadium and believes a deal to do so may be imminent It is the afternoon of 29 August, the day after a record-low crowd of 4,666 witnessed Hull crash to a 4-0 home defeat to Derby in the Car…',
#    'publishedAt': '2018-09-05T09:00:53Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'negative',
#    'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'title': 'Hull City’s Ehab Allam: ‘We are detached emotionally from the fans’',
#    'url': 'https://www.theguardian.com/football/football-league-blog/2018/sep/05/hull-city-ehab-allam-emotionally-detached-fans-championship-football-league-blog',
#    'urlToImage': 'https://i.guim.co.uk/img/media/dfc6575ab6b580a3688fb3b689e29e7a3182cff5/57_55_5218_3131/master/5218.jpg?width=1200&height=630&quality=85&auto=format&usm=12&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvZDM1ODZhNWVmNTc4MTc1NmQyMWEzYjYzNWU1MTcxNDEvdGctZGVmYXVsdC5wbmc&s=2fae75dc1b6590702d8a6cbbe401714e'},
#   {'author': 'Megan Reynolds',
#    'content': 'A New Jersey art teacher named Julia Mooney is attempting to teach her wards a lesson in sustainability by wearing the same dress 100 days in a row, reports the New York Post. Interesting! Really, though. It is. Mooney’s endeavor is not as gross as it necessa… [+2224 chars]',
#    'description': 'A New Jersey art teacher named Julia Mooney is attempting to teach her wards a lesson in sustainability by wearing the same dress 100 days in a row, reports the New York Post. Interesting! Really, though. It is. Read more...',
#    'publishedAt': '2018-09-14T18:55:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'negative',
#    'source': {'id': None, 'name': 'Jezebel.com'},
#    'title': 'What Outfit Would Your Stank Ass Wear for 100 Days in a Row?',
#    'url': 'https://jezebel.com/what-outfit-would-your-stank-ass-wear-for-100-days-in-a-1829064974',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/s--KYKLcZdm--/c_fill,fl_progressive,g_center,h_900,q_80,w_1600/xlsgigxqhxpjflmmlvqn.jpg'},
#   {'author': 'Fahrenkamp-Uppenbrink, J.',
#    'content': 'Thank you for your interest in spreading the word about Science. NOTE: We only request your email address so that the person you are recommending the page to knows that you wanted them to see it, and that it is not junk mail. We do not capture any email addre… [+2 chars]',
#    'description': 'Sustainability\nAccording to the Gaia hypothesis, living organisms and their inorganic environments form a self-regulating system that helps to maintain the conditions for life on Earth. In a Perspective, Lenton and Latour argue that Gaia is entering a new sta…',
#    'publishedAt': '2018-09-13T17:37:31Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Sciencemag.org'},
#    'title': 'Gaia enters a new state',
#    'url': 'http://science.sciencemag.org/content/361/6407/1083.15.full',
#    'urlToImage': 'http://science.sciencemag.org/content/361/6407/F1.medium.gif'},
#   {'author': None,
#    'content': 'In low-income countries, populations often depend on extractive industries such as fishing, agriculture and mining, but have lower per capita consumption rates and higher population growth. Credit: ARC CoE for Coral Reef Studies/Jacqueline Lau New research co… [+3119 chars]',
#    'description': "New research confronts the elephant in the room—the 'trilemma' of population growth, economic growth and environmental sustainability—and reveals the vast incompatibility of current models of economic development with environmental sustainability.",
#    'publishedAt': '2018-09-05T13:18:54Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Phys.org'},
#    'title': 'Can sustainable development co-exist with current economic growth?',
#    'url': 'https://phys.org/news/2018-09-sustainable-co-exist-current-economic-growth.html',
#    'urlToImage': 'https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/2018/cansustainab.jpg'},
#   {'author': 'Dara Prant',
#    'content': "Donatella Versace and Cindy Crawford in Versace at the 2018 Green Carpet Fashion Awards. Photo: Dave Benett/Getty Images On Sunday evening, models, Hollywood starlets and designers gathered at Milan's La Scala for the Green Carpet Fashion Awards. The event is… [+2246 chars]",
#    'description': "On Sunday evening, models, Hollywood starlets and designers gathered at Milan's La Scala for the Green Carpet Fashion Awards. The event is put on by Eco-Age — a sustainability and communications consultancy — and honors the commitment of luxury fashion houses…",
#    'publishedAt': '2018-09-24T19:00:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Fashionista.com'},
#    'title': 'Industry Icons Got Dressed up in Sustainably Made Gowns for the Green Carpet Fashion Awards',
#    'url': 'https://fashionista.com/2018/09/2018-green-carpet-fashion-awards-best-dressed',
#    'urlToImage': 'https://fashionista.com/.image/t_share/MTU4Njc5MTUwNzg4MzU1NTA1/green-carpet-fashion-awards.png'},
#   {'author': 'Lydia Ramsey',
#    'content': 'In the future, the plastic used in your grocery bags, coffee pods, or clothing might be produced by microbes. One company in the space, Genomatica, is using biotechnology to produce the chemicals needed to make plastic bags. On Wednesday, Genomatica raised $9… [+2414 chars]',
#    'description': 'San Diego-based Genomatica announced on Wednesday it has raised $90 million to apply its approach of using microbes to produce biodegradable chemicals to more projects. So far, Genomatica can produce two chemicals used in plastic bags and cosmetic products. I…',
#    'publishedAt': '2018-10-03T10:00:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'title': "A company that's using microbes to produce biodegradable materials for everything from plastic bags to clothing just raised $90 million",
#    'url': 'https://www.businessinsider.com/genomatica-raises-90-million-for-synthetic-biology-materials-manufacturing-2018-10',
#    'urlToImage': 'https://amp.businessinsider.com/images/5bb3e453190907225a37a72c-2732-1366.jpg'},
#   {'author': 'Finn Faldi',
#    'content': "September 27, 2018 7 min read Opinions expressed by Entrepreneur contributors are their own. Investing in a startup within the first year can be both thrilling and nerve-wracking, but it's best to keep your heart rate steady, your mind open and your eyes clea… [+7092 chars]",
#    'description': 'To sustain success, focus on your customers.',
#    'publishedAt': '2018-09-27T15:30:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Entrepreneur.com'},
#    'title': "There's No Guarantee Sudden Startup Success Will Last. Here's What You Need to Do to Achieve Long-Term Growth.",
#    'url': 'https://www.entrepreneur.com/article/320257',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/20180925193243-GettyImages-740534235.jpeg'},
#   {'author': 'Thomas Smale',
#    'content': 'September 19, 2018 7 min read Opinions expressed by Entrepreneur contributors are their own. Every business -- large or small, online or offline -- relies on processes. These can be simple or complex, but most businesses boast a mixture of both. Related: The … [+7403 chars]',
#    'description': "SOPs can reduce the need for owner involvement and increase a company's valuation at the time of sale.",
#    'publishedAt': '2018-09-19T15:00:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Entrepreneur.com'},
#    'title': "The ABC's of Documenting Standard Operating Procedures -- and Why Your Business Can't Afford Not To",
#    'url': 'https://www.entrepreneur.com/article/320266',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/20180919142454-GettyImages-878052550.jpeg'},
#   {'author': 'Adele Peters',
#    'content': 'Two-thirds of the wool produced by a flock of sheep at Bare Ranch, a large ranch in Northern California, is now going to The North Face. The ranch was the first to adopt a so-called “carbon farm plan” to change its practices to help reverse its own emissions,… [+2299 chars]',
#    'description': 'The North Face is expanding its line of “climate beneficial wool” to include jackets and scarves. Two-thirds of the wool produced by a flock of sheep at Bare Ranch, a large ranch in Northern California, is now going to The North Face. Read Full Story',
#    'publishedAt': '2018-09-12T12:00:43Z',
#    'sentiment_classifier': 'negative',
#    'sentiment_sia': 'negative',
#    'source': {'id': None, 'name': 'Fastcompany.com'},
#    'title': 'These jackets are made from wool that fights climate change',
#    'url': 'https://www.fastcompany.com/90234633/these-jackets-are-made-from-wool-that-fights-climate-change?partner=feedburner&utm_source=feedburner&utm_medium=feed&utm_campaign=Feed%3A+fastcompany%2Fheadlines+%28Fast+Company%29',
#    'urlToImage': 'https://images.fastcompany.net/image/upload/w_1280,f_auto,q_auto,fl_lossy/wp-cms/uploads/2018/09/p-1-90234633-these-jackets-are-made-from-wool-that-fights-climate-change.jpg'},
#   {'author': None,
#    'content': 'Why isn’t sustainability a part of accounting training? Credit: Shutterstock It seems that everywhere we turn these days sustainability is a hot topic. From individuals to corporations, (almost) everyone is jumping on board with the idea that we all need to l… [+5469 chars]',
#    'description': 'It seems that everywhere we turn these days sustainability is a hot topic.  From individuals to corporations, (almost) everyone is jumping on board with the idea that we all need to live more sustainably.',
#    'publishedAt': '2018-09-17T13:00:03Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Phys.org'},
#    'title': "It's time to train accountants in sustainability",
#    'url': 'https://phys.org/news/2018-09-accountants-sustainability.html',
#    'urlToImage': 'https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/hires/2018/itstimetotra.jpg'},
#   {'author': None,
#    'content': 'Credit: CC0 Public Domain Last week, the California legislature voted to move to completely decarbonize its electric grid by 2045. As Ivan Penn observed in the New York Times : "The state\'s aggressiveness comes as the Trump administration is moving to loosen … [+8454 chars]',
#    'description': 'Last week, the California legislature voted to move to completely decarbonize its electric grid by 2045. As Ivan Penn observed in the New York Times:',
#    'publishedAt': '2018-09-04T15:10:01Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Phys.org'},
#    'title': 'California leads on sustainability innovation while Trump digs coal',
#    'url': 'https://phys.org/news/2018-09-california-sustainability-trump-coal.html',
#    'urlToImage': 'https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/hires/2018/1-electricvehi.jpg'},
#   {'author': 'Ben Hobson',
#    'content': "Tala co-founder Joshua Ward sets out his company's mission to be commercially successful while having a positive impact on the environment in this movie Dezeen produced for the London lighting brand. Tala is a British lighting brand based on Vyner Street in e… [+4890 chars]",
#    'description': "Tala co-founder Joshua Ward sets out his company's mission to be commercially successful while having a positive impact on the environment in this movie Dezeen produced for the London lighting brand. Tala is a British lighting brand based on Vyner Street in e…",
#    'publishedAt': '2018-09-06T08:52:04Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Dezeen.com'},
#    'title': 'Tala sets out to prove that "good design can help mitigate climate change"',
#    'url': 'http://www.dezeen.com/2018/09/06/video-interview-tala-lighting-light-bulbs-movie/',
#    'urlToImage': 'https://static.dezeen.com/uploads/2018/09/Tala-Studios-Vyner-Street-London_dezeen_tumbnail.jpg'},
#   {'author': None,
#    'content': 'An international team of researchers has outlined a plan for how to measure changes in key traits of animals and plants and provide these data to policymakers to improve natural resource management and keep nations on track to meet global biodiversity and sus… [+6529 chars]',
#    'description': 'An international team of researchers has outlined a plan for how to measure changes in key traits of animals and plants and provide these data to policymakers to improve natural resource management and keep nations on track to meet global biodiversity and sus…',
#    'publishedAt': '2018-09-17T15:16:37Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Sciencedaily.com'},
#    'title': 'Roadmap for measuring animal, plant traits to meet biodiversity goals',
#    'url': 'https://www.sciencedaily.com/releases/2018/09/180917111637.htm',
#    'urlToImage': '/images/2018/09/180917111637_1_540x360.jpg'},
#   {'author': 'Stephen J. Bronner',
#    'content': 'September 17, 2018 4 min read In this ongoing column, The Digest, Entrepreneur.com News Director Stephen J. Bronner speaks with food entrepreneurs and executives to see what it took to get their products into the mouths of customers. Even before Daniella Hunt… [+3454 chars]',
#    'description': 'The Real Coconut sells products that have proven popular at the Mexican hotel restaurant with the same name.',
#    'publishedAt': '2018-09-17T13:00:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Entrepreneur.com'},
#    'title': 'How She Built a Hotel in Mexico and Wound Up With a Packaged Food Company',
#    'url': 'https://www.entrepreneur.com/article/319757',
#    'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/20180911211929--S5A0843-crop.jpeg'},
#   {'author': 'BoF Team',
#    'content': 'LONDON, United Kingdom — The Business of Fashion is pleased to reveal its early speaker lineup for VOICES, BoF’s annual gathering for big thinkers, which will take place from November 28 to December 1, 2018 in partnership with QIC Global Real Estate. VOICES i… [+20210 chars]',
#    'description': 'McCartney will also receive the 2018 Global VOICES Award for her pioneering work in the field of sustainability within the fashion space.',
#    'publishedAt': '2018-09-06T05:30:20Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Businessoffashion.com'},
#    'title': 'Stella McCartney, Alber Elbaz, Christopher Wylie and Riz Ahmed to Headline VOICES 2018',
#    'url': 'https://www.businessoffashion.com/articles/voices/stella-mccartney-alber-elbaz-christopher-wylie-and-riz-ahmed-to-headline-bof-voices-2018',
#    'urlToImage': 'https://images.businessoffashion.com/site/uploads/2018/09/voices-lead-image.jpg?crop=faces%2Centropy&fit=crop&max-h=512&w=1024'},
#   {'author': 'Lauren Cochrane in Paris',
#    'content': 'I t was a grey autumnal day in Paris. But at the Chanel show in the Grand Palais, Karl Lagerfeld ensured that summer stuck around for a bit longer. The designer, who previously brought a Chanel supermarket and a rocket bearing the brands signature double C lo… [+3243 chars]',
#    'description': 'Grand Palais in Paris decked out with blue sky and sandy shore for spring-summer 2019 collection It was a grey autumnal day in Paris. But at the Chanel show in the Grand Palais, Karl Lagerfeld ensured that summer stuck around for a bit longer. The designer, w…',
#    'publishedAt': '2018-10-02T15:27:42Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'title': 'Karl Lagerfeld makes waves with catwalk beach at Chanel show',
#    'url': 'https://www.theguardian.com/fashion/2018/oct/02/karl-lagerfeld-catwalk-beach-chanel-show-paris-fashion-week',
# ...
#    'description': 'To mark the 70th anniversary of the NHS, healthcare staff and residents in Tameside went sugar-free for 70 days When the Labour deputy leader, Tom Watson, told me he’d found it “relatively easy” to los e 94lbs in 10 months after following the plan outlined in…',
#    'publishedAt': '2018-09-28T10:53:22Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'the-guardian-au', 'name': 'The Guardian (AU)'},
#    'title': 'What can the town that gave up sugar teach us about diabetes and obesity? | Aseem Malhotra',
#    'url': 'https://www.theguardian.com/society/2018/sep/28/town-gave-up-sugar-diabetes-obesity',
#    'urlToImage': 'https://i.guim.co.uk/img/media/3ab18dc5d0c7638a1c9ff6035a51c5f1626d047e/0_23_5760_3456/master/5760.jpg?width=1200&height=630&quality=85&auto=format&fit=crop&crop=faces%2Centropy&bm=normal&ba=bottom%2Cleft&blend64=aHR0cHM6Ly9hc3NldHMuZ3VpbS5jby51ay9pbWFnZXMvb3ZlcmxheXMvNTM4OGZjODViNTQ0N2E4M2NmMWNlMTg5YTVhMjE1NzMvdGctb3BpbmlvbnMucG5n&s=5837c21cfd36def9217803857c173c44'},
#   {'author': 'Gavin Clarke',
#    'content': "We're digging into rare earth minerals with The Register 's next Lecture in October. Dr Teal Riley, head of the Geological Mapping Group at the British Antarctic Survey, will discuss with Register readers a joint University of Cambridge project which hopes to… [+1221 chars]",
#    'description': "Pipe down, Michael Stipe, we want tech's precious rock star We're digging into rare earth minerals with The Register 's next Lecture in October.…",
#    'publishedAt': '2018-09-12T13:01:01Z',
#    'sentiment_classifier': 'negative',
#    'sentiment_sia': 'negative',
#    'source': {'id': None, 'name': 'Theregister.co.uk'},
#    'title': 'Has anyone seen REM lately? No, we mean rare earth minerals',
#    'url': 'https://www.theregister.co.uk/2018/09/12/the_register_lecture_rems_from_above/',
#    'urlToImage': 'https://regmedia.co.uk/2018/09/11/the-overhead-plot-to-uncover-rare-earth-minerals.jpg?x=1200&y=794'},
#   {'author': 'Erin',
#    'content': 'kt814 architects have designed a new house in Jackson Hole, Wyoming, that’s been designed as a series of three connected pavilions. Sustainability, low maintenance costs, privacy, and unobstructed views, were all key factors that had to be considered when des… [+1714 chars]',
#    'description': 'Photography by David Agnello kt814 architects have designed a new house in Jackson Hole, Wyoming, that’s been designed as a series of three connected pavilions. Photography by David Agnello Sustainability, low maintenance costs, privacy, and unobstructed view…',
#    'publishedAt': '2018-09-12T21:47:35Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Contemporist.com'},
#    'title': 'This House In Wyoming Uses Dark And Light Wood To Create A Two-Toned Facade',
#    'url': 'http://www.contemporist.com/house-uses-dark-and-light-wood-to-create-a-two-toned-facade/',
#    'urlToImage': 'http://www.contemporist.com/wp-content/uploads/2018/09/modern-wood-house-architecture-120918-118-10.jpg'},
#   {'author': 'JONAH ENGEL BROMWICH',
#    'content': "Of course, one could also intuit that the rise of the chains cuts down on food waste, because the vegetables are coming pre-apportioned rather than piling up in bulk at home. But the container problem remains. Sweetgreens most serious competitors Chop't, Tend… [+1540 chars]",
#    'description': 'Popular fast-casual chains brag of sustainability, as customers toss their compostable and recyclable bowls into the trash with wild abandon.',
#    'publishedAt': '2018-09-29T10:00:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': 'the-new-york-times', 'name': 'The New York Times'},
#    'title': 'Is Your Salad Habit Good for the Planet?',
#    'url': 'https://www.nytimes.com/2018/09/29/style/healthy-bowls-salad-waste.html',
#    'urlToImage': 'https://static01.nyt.com/images/2018/09/30/style/30saladbowls3/30saladbowls3-facebookJumbo.jpg'},
#   {'author': 'feedback@businessinsider.com (Sam Jacobs), Sam Jacobs',
#    'content': 'Chinese online retailing giant Alibaba has announced that founder Jack Ma will step down as chairman, one year from today. In accordance with succession plans previously flagged by the company, current Alibaba CEO Daniel Zhang will succeed Ma as chairman on S… [+7394 chars]',
#    'description': 'Sean Gallup/Getty Images Jack Ma, the founder of online Chinese retailing giant Alibaba, will step down as Chairman on September 10, 2019. Ma will be succeeded by Daniel Zhang, Alibaba’s current CEO. Ma wrote a letter to customers and shareholders explaining …',
#    'publishedAt': '2018-09-10T02:43:40Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'business-insider', 'name': 'Business Insider'},
#    'title': 'Jack Ma will step down as Chairman of Chinese e-commerce giant Alibaba in September 2019',
#    'url': 'https://www.businessinsider.com/alibaba-jack-ma-retiring-as-chairman-2018-9',
#    'urlToImage': 'https://amp.businessinsider.com/images/58ecf3bc8af578521f8b4ea0-1136-568.jpg'},
#   {'author': None,
#    'content': 'According to the JRC, the global seafood consumption has more than doubled in the past 50 years, putting stress on the sustainability of fishing. Credit: AdobeStock, Alexander Raths The Joint Research Centre of the European Commission have examined the impact… [+5371 chars]',
#    'description': 'The Joint Research Centre of the European Commission have examined the impact of seafood supply chains across national boundaries—the global seafood consumption footprint.',
#    'publishedAt': '2018-09-28T13:50:03Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Phys.org'},
#    'title': 'How much fish do we consume? First global seafood consumption footprint published',
#    'url': 'https://phys.org/news/2018-09-fish-consume-global-seafood-consumption.html',
#    'urlToImage': 'https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/2018/howmuchfishd.jpg'},
#   {'author': 'Cynthia Bowman',
#    'content': 'If you’re getting ready to move, you probably have an idea of the basic moving supplies you’ll need: boxes, tape and paper. However, we’ve compiled ten smart moving supplies you’ll want to add to make your move easier. These eco-friendly options will organize… [+2812 chars]',
#    'description': 'If you’re getting ready to move, you probably have an idea of the basic moving supplies you’ll need: boxes, tape and paper. However, we’ve compiled ten smart moving supplies you’ll want to add to make your move easier. These eco-friendly options will organize…',
#    'publishedAt': '2018-09-11T12:00:47Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Freshome.com'},
#    'title': '10 Smart Moving Supplies That Will Make Moving Easier',
#    'url': 'https://freshome.com/moving-supplies/',
#    'urlToImage': 'https://cdn.freshome.com/wp-content/uploads/2018/08/bin-it.jpg'},
#   {'author': None,
#    'content': 'Climate change also has an impact on public health. Credit: Shutterstock A half-century ago, concerns about climate change, environment vulnerability, population density and the sustainability of earth systems reached a broad audience. This was clear from boo… [+5398 chars]',
#    'description': 'A half-century ago, concerns about climate change, environment vulnerability, population density and the sustainability of earth systems reached a broad audience. This was clear from books like the Silent Spring published in 1962, and The Limits to Growth pub…',
#    'publishedAt': '2018-09-17T13:20:02Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Phys.org'},
#    'title': 'Climate change, water and the spread of diseases: Connecting the dots differently',
#    'url': 'https://phys.org/news/2018-09-climate-diseases-dots-differently.html',
#    'urlToImage': 'https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/2018/92-climatechang.jpg'},
#   {'author': None,
#    'content': "GEO BON has identified six classes of 'essential biodiversity variables' to track and monitor, represented by the teal dots at the top of this figure. Guralnick and his colleagues refined the 'species traits' class by defining characteristics to measure and l… [+7640 chars]",
#    'description': 'An international team of researchers has outlined a plan for how to measure changes in key traits of animals and plants and provide these data to policymakers to improve natural resource management and keep nations on track to meet global biodiversity and sus…',
#    'publishedAt': '2018-09-17T15:12:48Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Phys.org'},
#    'title': 'Study provides roadmap for measuring animal, plant traits to meet biodiversity goals',
#    'url': 'https://phys.org/news/2018-09-roadmap-animal-traits-biodiversity-goals.html',
#    'urlToImage': 'https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/hires/2018/4-studyprovide.jpg'},
#   {'author': 'Victoria Moss',
#    'content': 'E nter Amy Powney, the forceful 34 year old creative director of the small label Mother of Pearl which shows at London Fashion Week. For her, sustainability is a mindset and “way of life” which she, having grown up off-grid living in a caravan in the middle o… [+851 chars]',
#    'description': 'Increasingly, the fashion industry is toying more seriously with sustainability.',
#    'publishedAt': '2018-09-04T14:16:48Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': 'the-telegraph', 'name': 'The Telegraph'},
#    'title': "'Sustainability means nothing and everything all at once': Mother of Pearl's Amy Powney on her mission to reframe how we consume fashion",
#    'url': 'https://www.telegraph.co.uk/fashion/brands/sustainability-means-nothing-everything-mother-pearls-amy-powney/',
#    'urlToImage': 'https://www.telegraph.co.uk/content/dam/fashion/2018/09/04/TELEMMGLPICT000172390873-xlarge_trans_NvBQzQNjv4Bqtt-PMhmmlxqdgRPvuJG6C1jSXUMD6a1qhWMgiZzdDhI.jpeg'},
#   {'author': 'Steve Banker, Contributor, Steve Banker, Contributor https://www.forbes.com/sites/stevebanker/',
#    'content': "Share to facebook Share to twitter Share to linkedin Corporate Knight Produces a Report on the World's Most Sustainable Companies Corporate Knight Every year Corporate Knights puts out a report ranking the world's most sustainable companies. This year Dassaul… [+9790 chars]",
#    'description': "Dassault Systemes is the world's most sustainable company. Amazon has the least. Amazon is working to improve, but not in transportation. And it is the delivery of all those packages where their supply chain creates the greatest adverse impacts on the environ…",
#    'publishedAt': '2018-09-20T16:41:00Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Forbes.com'},
#    'title': 'The Best And Worst In Sustainability: Dassault Systèmes Versus Amazon',
#    'url': 'https://www.forbes.com/sites/stevebanker/2018/09/20/the-best-and-worst-in-sustainability-dassault-systemes-versus-amazon/',
#    'urlToImage': 'https://thumbor.forbes.com/thumbor/600x315/https%3A%2F%2Fblogs-images.forbes.com%2Fstevebanker%2Ffiles%2F2018%2F09%2FCorporateKnight-e1537460623920.jpg'},
#   {'author': 'Lili',
#    'content': "ga('send', 'event', 'Uncategorized', 'article', 'article-industry-impression', {nonInteraction: true}); As sustainability gains increasing traction, it is unsurprising to see a rise in the use of natural building materials. For example, engineers can strength… [+1734 chars]",
#    'description': 'Sri Lankan paint company created a symbolic temple paint using waste from Buddhist flower offerings. Sri Lankan paint company created a symbolic temple paint using waste from Buddhist flower offerings.',
#    'publishedAt': '2018-09-03T05:15:54Z',
#    'sentiment_classifier': 'positive',
#    'sentiment_sia': 'positive',
#    'source': {'id': None, 'name': 'Springwise.com'},
#    'title': 'Paint made from flowers used to restore temple art',
#    'url': 'https://www.springwise.com/paint-made-from-flowers-used-to-restore-temple-art/',
#    'urlToImage': 'https://d1udjo59ytjrp6.cloudfront.net/img/uploads/2018/08/26161607/Petal_paint_sri_lanka_temple_restoration_Sprinwise.jpg'},
#   {'author': None,
#    'content': "Credit: CC0 Public Domain More private banks are offering sustainable investment options to wealthy clients. How do these products differ from one another? And do the banks' advisory services meet the expectations of investors? A study by the University of Zu… [+5202 chars]",
#    'description': "More private banks are offering sustainable investment options to wealthy clients. How do these products differ from one another? And do the banks' advisory services meet the expectations of investors? A study by the University of Zurich into the products and…",
#    'publishedAt': '2018-09-21T10:50:11Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Phys.org'},
#    'title': 'Banks do too little to communicate their sustainable investment products',
#    'url': 'https://phys.org/news/2018-09-banks-sustainable-investment-products.html',
#    'urlToImage': 'https://3c1703fe8d.site.internapcdn.net/newman/gfx/news/hires/2017/bank.jpg'},
#   {'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'content': 'Timberland recently launched an immersive green space at Bread&amp;&amp;Butter Berlin last weekend. The space hosted workshops where guests could create their own sustainable products, including Christopher Raeburn ‘s iconic repurposed parachute tote bags, wi… [+1399 chars]',
#    'description': "Timberland recently launched an immersive green space at Bread&&Butter Berlin last weekend. The space hosted workshops where guests could create their own sustainable products, including Christopher Raeburn's iconic repurposed parachute tote bags, with guidan…",
#    'publishedAt': '2018-09-05T09:58:10Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Hypebeast.com'},
#    'title': 'Timberland and Christopher Raeburn Host Green Space at Bread&&Butter Berlin',
#    'url': 'https://hypebeast.com/2018/9/timberland-bread-butter-tradeshow-2018-christopher-raeburn',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2018%2F09%2Ftimberland-bread-butter-2018-tw.jpg?w=960&cbr=1&q=90&fit=max'},
#   {'author': 'info@hypebeast.com (HYPEBEAST), HYPEBEAST',
#    'content': 'After opening an Apple Store-like space in Chicago, McDonald’s has now returned to the city to open its global headquarters. Located in Chicago’s West Loop neighborhood, the new space marks the company’s return to the city where it was based between 1955 and … [+1075 chars]',
#    'description': "After opening an Apple Store-like space in Chicago, McDonald's has now returned to the city to open its global headquarters. Located in Chicago's West Loop neighborhood, the new space marks the company's return to the city where it was based between 1955 and …",
#    'publishedAt': '2018-09-11T11:07:05Z',
#    'sentiment_classifier': 'neutral',
#    'sentiment_sia': 'neutral',
#    'source': {'id': None, 'name': 'Hypebeast.com'},
#    'title': 'Take a Look Inside McDonald’s $250 Million USD Global HQ in Chicago',
#    'url': 'https://hypebeast.com/2018/9/mcdonalds-chicago-global-hq-opening',
#    'urlToImage': 'https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fimage%2F2018%2F09%2Fmcdonalds-chicago-global-hq-opening-0-tw.jpg?w=960&cbr=1&q=90&fit=max'}],
#  'totalResults': 5963}
